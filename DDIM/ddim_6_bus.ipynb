# %%
# !pip install --upgrade --force-reinstall numpy==1.26.4 scipy==1.13.1 pandapower==2.14.6 pot
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# Collecting scipy==1.13.1
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.7 MB/s eta 0:00:00
# Collecting pandapower==2.14.6
#   Downloading pandapower-2.14.6.zip (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pot
#   Downloading pot-0.9.6.post1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.1 MB/s eta 0:00:00
# Collecting pandas>=1.0 (from pandapower==2.14.6)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.1 MB/s eta 0:00:00
# Collecting networkx>=2.5 (from pandapower==2.14.6)
#   Downloading networkx-3.6-py3-none-any.whl.metadata (6.8 kB)
# Collecting packaging (from pandapower==2.14.6)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting tqdm (from pandapower==2.14.6)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.3 MB/s eta 0:00:00
# Collecting deepdiff (from pandapower==2.14.6)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=1.0->pandapower==2.14.6)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.0->pandapower==2.14.6)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.0->pandapower==2.14.6)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff->pandapower==2.14.6)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=1.0->pandapower==2.14.6)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 125.9 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 20.1 MB/s eta 0:00:00
# Downloading pot-0.9.6.post1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.4 MB/s eta 0:00:00
# Downloading networkx-3.6-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.6 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 142.6 MB/s eta 0:00:00
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 7.6 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 6.3 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.3 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 20.2 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 38.8 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 32.0 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: pandapower
#   Building wheel for pandapower (setup.py) ... done
#   Created wheel for pandapower: filename=pandapower-2.14.6-py3-none-any.whl size=13130929 sha256=8fa8317341366a0541a69965a44d72978a32bc0885e68dc508266abb18f8995f
#   Stored in directory: /root/.cache/pip/wheels/87/3e/01/95a23c22446c394ec5103e6cf4bedb084124a35f8d6363eb2f
# Successfully built pandapower
# Installing collected packages: pytz, tzdata, tqdm, six, packaging, orderly-set, numpy, networkx, scipy, python-dateutil, deepdiff, pot, pandas, pandapower
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# Successfully installed deepdiff-8.6.1 networkx-3.6 numpy-1.26.4 orderly-set-5.5.0 packaging-25.0 pandapower-2.14.6 pandas-2.3.3 pot-0.9.6.post1 python-dateutil-2.9.0.post0 pytz-2025.2 scipy-1.13.1 six-1.17.0 tqdm-4.67.1 tzdata-2025.2

# %%
import numpy as np
import pandas as pd
from scipy.stats import entropy
import pandapower as pp, pickle
import os, math, pickle
from tqdm import tqdm
import ot
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import grad
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
net = pp.networks.case6ww()
NUM_BUS = 6
BASE_MVA = 100

DATA_CSV = "actual_data_6.csv"
YBUS_NPZ = "Ybus.npz"
PANDAPOWER_NET_PKL = "pandapower_net.pkl"
OUT_CSV = "ddim_stochastic_constrained_generated.csv"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_FEATURES = 4 * NUM_BUS
BATCH_SIZE = 64
EPOCHS = 1000
LR = 1e-4
TIMESTEPS = 1000
DDIM_STEPS = 300
ETA = 0.2
SAMPLE_COUNT = 5000
GUIDANCE_LAMBDA = 1e-4

# %%
if not os.path.exists(DATA_CSV):
    raise FileNotFoundError("Need actual_data.csv generated from PF dataset code.")
actual = pd.read_csv(DATA_CSV)
cols = actual.columns.tolist()
if actual.shape[1] != NUM_FEATURES:
    raise ValueError(f"Dataset must have {NUM_FEATURES} columns.")
data = actual.values.astype(np.float32)

def load_ybus():
    nb = len(net.bus)
    Y = np.zeros((nb, nb), dtype=complex)
    for _, row in net.line.iterrows():
        i, j = int(row["from_bus"]), int(row["to_bus"])
        r, x = row["r_ohm_per_km"], row["x_ohm_per_km"]
        length = row.get("length_km", 1.0)
        y = 1 / complex(r * length, x * length)
        Y[i, i] += y; Y[j, j] += y; Y[i, j] -= y; Y[j, i] -= y
    return np.real(Y), np.imag(Y)

G_np, B_np = load_ybus()
G = torch.tensor(G_np, dtype=torch.float32, device=DEVICE)
B = torch.tensor(B_np, dtype=torch.float32, device=DEVICE)

xmin, xmax = data.min(axis=0), data.max(axis=0)
range_eps = (xmax - xmin).copy()
range_eps[range_eps == 0] = 1e-6

def normalize(x):
    return 2 * (x - xmin) / range_eps - 1

def denormalize(xn):
    return ((xn + 1) / 2) * range_eps + xmin

data_tensor = torch.tensor(normalize(data), dtype=torch.float32, device=DEVICE)

def split_vec(x):
    p, q, v, th = x[:, :NUM_BUS], x[:, NUM_BUS:2*NUM_BUS], \
                  x[:, 2*NUM_BUS:3*NUM_BUS], x[:, 3*NUM_BUS:4*NUM_BUS]
    return torch.cat([p, th], 1), torch.cat([q, v], 1)

def concat_vec(x1, x2):
    p, th = x1[:, :NUM_BUS], x1[:, NUM_BUS:]
    q, v  = x2[:, :NUM_BUS], x2[:, NUM_BUS:]
    return torch.cat([p, q, v, th], 1)

def linear_beta_schedule(T, start=1e-4, end=0.02):
    return torch.linspace(start, end, T, device=DEVICE)

betas = linear_beta_schedule(TIMESTEPS)
alphas = 1 - betas
alphas_cumprod = torch.cumprod(alphas, 0)

class MLPDenoiser(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim + 1, 4096), nn.LayerNorm(4096), nn.SiLU(),
            nn.Linear(4096, 4096), nn.LayerNorm(4096), nn.SiLU(),
            nn.Linear(4096, 4096), nn.LayerNorm(4096), nn.SiLU(),
            nn.Linear(4096, dim)
        )

    def forward(self, x, t):
        t = t.float().unsqueeze(1) / TIMESTEPS
        return self.net(torch.cat([x, t], 1))

model_dim = 4 * NUM_BUS
model = MLPDenoiser(model_dim).to(DEVICE)
opt = optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-3, betas=(0.9, 0.999))
mse = nn.MSELoss()

train_data, val_data = train_test_split(data_tensor, test_size=0.1, random_state=42)
Ntrain, Nval = train_data.shape[0], val_data.shape[0]

print("Training denoiser with validation monitoring...")
best_val = float("inf")

for ep in range(EPOCHS):
    model.train()
    perm = torch.randperm(Ntrain, device=DEVICE)
    tot_loss = 0.0

    for i in range(0, Ntrain, BATCH_SIZE):
        b = train_data[perm[i:i+BATCH_SIZE]]
        x = b
        Bc = x.size(0)
        if Bc == 0:
            continue

        t = torch.randint(0, TIMESTEPS, (Bc,), device=DEVICE)

        eps = torch.randn_like(x)

        sA = torch.sqrt(alphas_cumprod[t]).unsqueeze(1)
        sO = torch.sqrt(1 - alphas_cumprod[t]).unsqueeze(1)

        x_t = sA * x + sO * eps

        pred = model(x_t, t)

        loss = mse(pred, eps)

        opt.zero_grad()
        loss.backward()
        opt.step()

        tot_loss += loss.item() * Bc

    train_loss = tot_loss / Ntrain

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for i in range(0, Nval, BATCH_SIZE):
            b = val_data[i:i+BATCH_SIZE]
            x = b
            Bc = x.size(0)
            if Bc == 0:
                continue
            t = torch.randint(0, TIMESTEPS, (Bc,), device=DEVICE)
            eps = torch.randn_like(x)
            sA = torch.sqrt(alphas_cumprod[t]).unsqueeze(1)
            sO = torch.sqrt(1 - alphas_cumprod[t]).unsqueeze(1)
            x_t = sA * x + sO * eps
            pred = model(x_t, t)
            val_loss += mse(pred, eps).item() * Bc
    val_loss /= Nval

    print(f"Epoch {ep+1:4d}/{EPOCHS} | Train Loss: {train_loss:.6f} | Val Loss: {val_loss:.6f}")

    if val_loss < best_val:
        best_val = val_loss
        torch.save({
            "model": model.state_dict(),
            "opt": opt.state_dict(),
            "epoch": ep,
            "val_loss": val_loss
        }, "best_ddim_denoiser.pth")
        print(f"  New best model saved (val_loss={val_loss:.6f})")

print("Training done.\n")
# Out:
# Training denoiser with validation monitoring...
# Epoch    1/1000 | Train Loss: 0.157068 | Val Loss: 0.094875
#   New best model saved (val_loss=0.094875)
# Epoch    2/1000 | Train Loss: 0.090778 | Val Loss: 0.089956
#   New best model saved (val_loss=0.089956)
# Epoch    3/1000 | Train Loss: 0.081243 | Val Loss: 0.073599
#   New best model saved (val_loss=0.073599)
# Epoch    4/1000 | Train Loss: 0.071551 | Val Loss: 0.075076
# Epoch    5/1000 | Train Loss: 0.071984 | Val Loss: 0.072293
#   New best model saved (val_loss=0.072293)
# Epoch    6/1000 | Train Loss: 0.067255 | Val Loss: 0.073622
# Epoch    7/1000 | Train Loss: 0.066459 | Val Loss: 0.061976
#   New best model saved (val_loss=0.061976)
# Epoch    8/1000 | Train Loss: 0.060789 | Val Loss: 0.059698
#   New best model saved (val_loss=0.059698)
# Epoch    9/1000 | Train Loss: 0.061413 | Val Loss: 0.056170
#   New best model saved (val_loss=0.056170)
# Epoch   10/1000 | Train Loss: 0.061775 | Val Loss: 0.060531
# Epoch   11/1000 | Train Loss: 0.060924 | Val Loss: 0.059329
# Epoch   12/1000 | Train Loss: 0.060214 | Val Loss: 0.064881
# Epoch   13/1000 | Train Loss: 0.059179 | Val Loss: 0.060178
# Epoch   14/1000 | Train Loss: 0.056249 | Val Loss: 0.055822
#   New best model saved (val_loss=0.055822)
# Epoch   15/1000 | Train Loss: 0.057716 | Val Loss: 0.062762
# Epoch   16/1000 | Train Loss: 0.055400 | Val Loss: 0.052082
#   New best model saved (val_loss=0.052082)
# Epoch   17/1000 | Train Loss: 0.058008 | Val Loss: 0.060880
# Epoch   18/1000 | Train Loss: 0.052767 | Val Loss: 0.050106
#   New best model saved (val_loss=0.050106)
# Epoch   19/1000 | Train Loss: 0.056616 | Val Loss: 0.051373
# Epoch   20/1000 | Train Loss: 0.054272 | Val Loss: 0.053720
# Epoch   21/1000 | Train Loss: 0.052406 | Val Loss: 0.052186
# Epoch   22/1000 | Train Loss: 0.052755 | Val Loss: 0.057511
# Epoch   23/1000 | Train Loss: 0.051103 | Val Loss: 0.051807
# Epoch   24/1000 | Train Loss: 0.051029 | Val Loss: 0.052224
# Epoch   25/1000 | Train Loss: 0.050343 | Val Loss: 0.049777
#   New best model saved (val_loss=0.049777)
# Epoch   26/1000 | Train Loss: 0.050166 | Val Loss: 0.047122
#   New best model saved (val_loss=0.047122)
# Epoch   27/1000 | Train Loss: 0.049349 | Val Loss: 0.050790
# Epoch   28/1000 | Train Loss: 0.052381 | Val Loss: 0.047141
# Epoch   29/1000 | Train Loss: 0.050229 | Val Loss: 0.050328
# Epoch   30/1000 | Train Loss: 0.050450 | Val Loss: 0.054936
# Epoch   31/1000 | Train Loss: 0.047288 | Val Loss: 0.058558
# Epoch   32/1000 | Train Loss: 0.047283 | Val Loss: 0.046312
#   New best model saved (val_loss=0.046312)
# Epoch   33/1000 | Train Loss: 0.050279 | Val Loss: 0.052877
# Epoch   34/1000 | Train Loss: 0.047542 | Val Loss: 0.054511
# Epoch   35/1000 | Train Loss: 0.048679 | Val Loss: 0.050287
# Epoch   36/1000 | Train Loss: 0.048269 | Val Loss: 0.050354
# Epoch   37/1000 | Train Loss: 0.046507 | Val Loss: 0.052768
# Epoch   38/1000 | Train Loss: 0.047112 | Val Loss: 0.046357
# Epoch   39/1000 | Train Loss: 0.046842 | Val Loss: 0.049280
# Epoch   40/1000 | Train Loss: 0.046335 | Val Loss: 0.044684
#   New best model saved (val_loss=0.044684)
# Epoch   41/1000 | Train Loss: 0.047086 | Val Loss: 0.043246
#   New best model saved (val_loss=0.043246)
# Epoch   42/1000 | Train Loss: 0.047668 | Val Loss: 0.051149
# Epoch   43/1000 | Train Loss: 0.046145 | Val Loss: 0.045518
# Epoch   44/1000 | Train Loss: 0.046203 | Val Loss: 0.049395
# Epoch   45/1000 | Train Loss: 0.045757 | Val Loss: 0.048408
# Epoch   46/1000 | Train Loss: 0.043354 | Val Loss: 0.043512
# Epoch   47/1000 | Train Loss: 0.044913 | Val Loss: 0.047103
# Epoch   48/1000 | Train Loss: 0.048516 | Val Loss: 0.046082
# Epoch   49/1000 | Train Loss: 0.045603 | Val Loss: 0.040259
#   New best model saved (val_loss=0.040259)
# Epoch   50/1000 | Train Loss: 0.043014 | Val Loss: 0.041483
# Epoch   51/1000 | Train Loss: 0.045561 | Val Loss: 0.050358
# Epoch   52/1000 | Train Loss: 0.047471 | Val Loss: 0.046910
# Epoch   53/1000 | Train Loss: 0.046472 | Val Loss: 0.041224
# Epoch   54/1000 | Train Loss: 0.044329 | Val Loss: 0.046736
# Epoch   55/1000 | Train Loss: 0.045701 | Val Loss: 0.055046
# Epoch   56/1000 | Train Loss: 0.043618 | Val Loss: 0.046581
# Epoch   57/1000 | Train Loss: 0.043490 | Val Loss: 0.043388
# Epoch   58/1000 | Train Loss: 0.043250 | Val Loss: 0.043722
# Epoch   59/1000 | Train Loss: 0.044557 | Val Loss: 0.048346
# Epoch   60/1000 | Train Loss: 0.045497 | Val Loss: 0.048146
# Epoch   61/1000 | Train Loss: 0.046115 | Val Loss: 0.043346
# Epoch   62/1000 | Train Loss: 0.045428 | Val Loss: 0.041864
# Epoch   63/1000 | Train Loss: 0.044578 | Val Loss: 0.047212
# Epoch   64/1000 | Train Loss: 0.043989 | Val Loss: 0.040872
# Epoch   65/1000 | Train Loss: 0.042728 | Val Loss: 0.043828
# Epoch   66/1000 | Train Loss: 0.045342 | Val Loss: 0.044328
# Epoch   67/1000 | Train Loss: 0.041906 | Val Loss: 0.043408
# Epoch   68/1000 | Train Loss: 0.043601 | Val Loss: 0.046547
# Epoch   69/1000 | Train Loss: 0.044268 | Val Loss: 0.046879
# Epoch   70/1000 | Train Loss: 0.042627 | Val Loss: 0.040708
# Epoch   71/1000 | Train Loss: 0.043517 | Val Loss: 0.049106
# Epoch   72/1000 | Train Loss: 0.043178 | Val Loss: 0.047163
# Epoch   73/1000 | Train Loss: 0.043982 | Val Loss: 0.044966
# Epoch   74/1000 | Train Loss: 0.043077 | Val Loss: 0.047784
# Epoch   75/1000 | Train Loss: 0.043415 | Val Loss: 0.041625
# Epoch   76/1000 | Train Loss: 0.042550 | Val Loss: 0.049490
# Epoch   77/1000 | Train Loss: 0.043430 | Val Loss: 0.044817
# Epoch   78/1000 | Train Loss: 0.041999 | Val Loss: 0.040680
# Epoch   79/1000 | Train Loss: 0.040862 | Val Loss: 0.041972
# Epoch   80/1000 | Train Loss: 0.042564 | Val Loss: 0.041062
# Epoch   81/1000 | Train Loss: 0.041887 | Val Loss: 0.047366
# Epoch   82/1000 | Train Loss: 0.043489 | Val Loss: 0.041755
# Epoch   83/1000 | Train Loss: 0.043197 | Val Loss: 0.045078
# Epoch   84/1000 | Train Loss: 0.042285 | Val Loss: 0.046125
# Epoch   85/1000 | Train Loss: 0.041764 | Val Loss: 0.039803
#   New best model saved (val_loss=0.039803)
# Epoch   86/1000 | Train Loss: 0.043082 | Val Loss: 0.040907
# Epoch   87/1000 | Train Loss: 0.041485 | Val Loss: 0.045048
# Epoch   88/1000 | Train Loss: 0.040444 | Val Loss: 0.037196
#   New best model saved (val_loss=0.037196)
# Epoch   89/1000 | Train Loss: 0.042258 | Val Loss: 0.046000
# Epoch   90/1000 | Train Loss: 0.044316 | Val Loss: 0.042460
# Epoch   91/1000 | Train Loss: 0.041878 | Val Loss: 0.038790
# Epoch   92/1000 | Train Loss: 0.042115 | Val Loss: 0.043719
# Epoch   93/1000 | Train Loss: 0.042353 | Val Loss: 0.041052
# Epoch   94/1000 | Train Loss: 0.041766 | Val Loss: 0.046088
# Epoch   95/1000 | Train Loss: 0.041042 | Val Loss: 0.041171
# Epoch   96/1000 | Train Loss: 0.043028 | Val Loss: 0.037861
# Epoch   97/1000 | Train Loss: 0.043993 | Val Loss: 0.045575
# Epoch   98/1000 | Train Loss: 0.042875 | Val Loss: 0.039811
# Epoch   99/1000 | Train Loss: 0.040995 | Val Loss: 0.046845
# Epoch  100/1000 | Train Loss: 0.042487 | Val Loss: 0.042130
# Epoch  101/1000 | Train Loss: 0.043882 | Val Loss: 0.045960
# Epoch  102/1000 | Train Loss: 0.041075 | Val Loss: 0.037652
# Epoch  103/1000 | Train Loss: 0.042256 | Val Loss: 0.037101
#   New best model saved (val_loss=0.037101)
# Epoch  104/1000 | Train Loss: 0.041470 | Val Loss: 0.039986
# Epoch  105/1000 | Train Loss: 0.041511 | Val Loss: 0.039325
# Epoch  106/1000 | Train Loss: 0.040736 | Val Loss: 0.045276
# Epoch  107/1000 | Train Loss: 0.041498 | Val Loss: 0.041432
# Epoch  108/1000 | Train Loss: 0.040680 | Val Loss: 0.039882
# Epoch  109/1000 | Train Loss: 0.043957 | Val Loss: 0.039008
# Epoch  110/1000 | Train Loss: 0.042057 | Val Loss: 0.045870
# Epoch  111/1000 | Train Loss: 0.040713 | Val Loss: 0.044245
# Epoch  112/1000 | Train Loss: 0.041283 | Val Loss: 0.041511
# Epoch  113/1000 | Train Loss: 0.040795 | Val Loss: 0.040185
# Epoch  114/1000 | Train Loss: 0.041197 | Val Loss: 0.046657
# Epoch  115/1000 | Train Loss: 0.040303 | Val Loss: 0.043712
# Epoch  116/1000 | Train Loss: 0.039745 | Val Loss: 0.041721
# Epoch  117/1000 | Train Loss: 0.040020 | Val Loss: 0.042182
# Epoch  118/1000 | Train Loss: 0.039870 | Val Loss: 0.041329
# Epoch  119/1000 | Train Loss: 0.043448 | Val Loss: 0.042404
# Epoch  120/1000 | Train Loss: 0.041105 | Val Loss: 0.040688
# Epoch  121/1000 | Train Loss: 0.040488 | Val Loss: 0.043585
# Epoch  122/1000 | Train Loss: 0.040308 | Val Loss: 0.045366
# Epoch  123/1000 | Train Loss: 0.040872 | Val Loss: 0.045027
# Epoch  124/1000 | Train Loss: 0.041259 | Val Loss: 0.042372
# Epoch  125/1000 | Train Loss: 0.041791 | Val Loss: 0.042525
# Epoch  126/1000 | Train Loss: 0.041765 | Val Loss: 0.043619
# Epoch  127/1000 | Train Loss: 0.039824 | Val Loss: 0.046388
# Epoch  128/1000 | Train Loss: 0.039730 | Val Loss: 0.039190
# Epoch  129/1000 | Train Loss: 0.041211 | Val Loss: 0.041133
# Epoch  130/1000 | Train Loss: 0.042139 | Val Loss: 0.042488
# Epoch  131/1000 | Train Loss: 0.041186 | Val Loss: 0.039286
# Epoch  132/1000 | Train Loss: 0.042146 | Val Loss: 0.040585
# Epoch  133/1000 | Train Loss: 0.038924 | Val Loss: 0.038117
# Epoch  134/1000 | Train Loss: 0.039120 | Val Loss: 0.038737
# Epoch  135/1000 | Train Loss: 0.039870 | Val Loss: 0.043769
# Epoch  136/1000 | Train Loss: 0.040033 | Val Loss: 0.041652
# Epoch  137/1000 | Train Loss: 0.040562 | Val Loss: 0.040327
# Epoch  138/1000 | Train Loss: 0.038718 | Val Loss: 0.037859
# Epoch  139/1000 | Train Loss: 0.039288 | Val Loss: 0.037573
# Epoch  140/1000 | Train Loss: 0.039619 | Val Loss: 0.038511
# Epoch  141/1000 | Train Loss: 0.039504 | Val Loss: 0.040325
# Epoch  142/1000 | Train Loss: 0.040995 | Val Loss: 0.040762
# Epoch  143/1000 | Train Loss: 0.042578 | Val Loss: 0.040803
# Epoch  144/1000 | Train Loss: 0.041905 | Val Loss: 0.038290
# Epoch  145/1000 | Train Loss: 0.041538 | Val Loss: 0.041467
# Epoch  146/1000 | Train Loss: 0.040835 | Val Loss: 0.040159
# Epoch  147/1000 | Train Loss: 0.039935 | Val Loss: 0.048295
# Epoch  148/1000 | Train Loss: 0.040638 | Val Loss: 0.043495
# Epoch  149/1000 | Train Loss: 0.039915 | Val Loss: 0.040996
# Epoch  150/1000 | Train Loss: 0.041404 | Val Loss: 0.041575
# Epoch  151/1000 | Train Loss: 0.041966 | Val Loss: 0.035140
#   New best model saved (val_loss=0.035140)
# Epoch  152/1000 | Train Loss: 0.039808 | Val Loss: 0.040385
# Epoch  153/1000 | Train Loss: 0.040471 | Val Loss: 0.038385
# Epoch  154/1000 | Train Loss: 0.042006 | Val Loss: 0.040275
# Epoch  155/1000 | Train Loss: 0.040190 | Val Loss: 0.038137
# Epoch  156/1000 | Train Loss: 0.038456 | Val Loss: 0.041565
# Epoch  157/1000 | Train Loss: 0.040032 | Val Loss: 0.041679
# Epoch  158/1000 | Train Loss: 0.039867 | Val Loss: 0.040642
# Epoch  159/1000 | Train Loss: 0.040822 | Val Loss: 0.040933
# Epoch  160/1000 | Train Loss: 0.040436 | Val Loss: 0.037209
# Epoch  161/1000 | Train Loss: 0.039586 | Val Loss: 0.049175
# Epoch  162/1000 | Train Loss: 0.041317 | Val Loss: 0.037833
# Epoch  163/1000 | Train Loss: 0.038299 | Val Loss: 0.040264
# Epoch  164/1000 | Train Loss: 0.038581 | Val Loss: 0.040080
# Epoch  165/1000 | Train Loss: 0.040300 | Val Loss: 0.038806
# Epoch  166/1000 | Train Loss: 0.038729 | Val Loss: 0.037097
# Epoch  167/1000 | Train Loss: 0.040940 | Val Loss: 0.039636
# Epoch  168/1000 | Train Loss: 0.038498 | Val Loss: 0.037846
# Epoch  169/1000 | Train Loss: 0.039905 | Val Loss: 0.038400
# Epoch  170/1000 | Train Loss: 0.040741 | Val Loss: 0.039155
# Epoch  171/1000 | Train Loss: 0.039631 | Val Loss: 0.040924
# Epoch  172/1000 | Train Loss: 0.039486 | Val Loss: 0.038958
# Epoch  173/1000 | Train Loss: 0.038753 | Val Loss: 0.039064
# Epoch  174/1000 | Train Loss: 0.038785 | Val Loss: 0.042949
# Epoch  175/1000 | Train Loss: 0.039115 | Val Loss: 0.040849
# Epoch  176/1000 | Train Loss: 0.038561 | Val Loss: 0.038479
# Epoch  177/1000 | Train Loss: 0.039724 | Val Loss: 0.037948
# Epoch  178/1000 | Train Loss: 0.040505 | Val Loss: 0.041083
# Epoch  179/1000 | Train Loss: 0.039398 | Val Loss: 0.036979
# Epoch  180/1000 | Train Loss: 0.041402 | Val Loss: 0.040545
# Epoch  181/1000 | Train Loss: 0.040179 | Val Loss: 0.042706
# Epoch  182/1000 | Train Loss: 0.039415 | Val Loss: 0.042641
# Epoch  183/1000 | Train Loss: 0.041350 | Val Loss: 0.037377
# Epoch  184/1000 | Train Loss: 0.040314 | Val Loss: 0.038791
# Epoch  185/1000 | Train Loss: 0.040248 | Val Loss: 0.041692
# Epoch  186/1000 | Train Loss: 0.038513 | Val Loss: 0.045305
# Epoch  187/1000 | Train Loss: 0.038053 | Val Loss: 0.044219
# Epoch  188/1000 | Train Loss: 0.039448 | Val Loss: 0.044122
# Epoch  189/1000 | Train Loss: 0.041032 | Val Loss: 0.043922
# Epoch  190/1000 | Train Loss: 0.036318 | Val Loss: 0.038834
# Epoch  191/1000 | Train Loss: 0.039641 | Val Loss: 0.037438
# Epoch  192/1000 | Train Loss: 0.038032 | Val Loss: 0.044093
# Epoch  193/1000 | Train Loss: 0.038654 | Val Loss: 0.038522
# Epoch  194/1000 | Train Loss: 0.041794 | Val Loss: 0.040950
# Epoch  195/1000 | Train Loss: 0.039251 | Val Loss: 0.036859
# Epoch  196/1000 | Train Loss: 0.038129 | Val Loss: 0.039968
# Epoch  197/1000 | Train Loss: 0.039213 | Val Loss: 0.040897
# Epoch  198/1000 | Train Loss: 0.039438 | Val Loss: 0.038289
# Epoch  199/1000 | Train Loss: 0.040481 | Val Loss: 0.039075
# Epoch  200/1000 | Train Loss: 0.041544 | Val Loss: 0.038537
# Epoch  201/1000 | Train Loss: 0.039200 | Val Loss: 0.039645
# Epoch  202/1000 | Train Loss: 0.038837 | Val Loss: 0.042290
# Epoch  203/1000 | Train Loss: 0.039471 | Val Loss: 0.038357
# Epoch  204/1000 | Train Loss: 0.040188 | Val Loss: 0.037324
# Epoch  205/1000 | Train Loss: 0.039227 | Val Loss: 0.043100
# Epoch  206/1000 | Train Loss: 0.039004 | Val Loss: 0.035777
# Epoch  207/1000 | Train Loss: 0.039087 | Val Loss: 0.042902
# Epoch  208/1000 | Train Loss: 0.039864 | Val Loss: 0.039124
# Epoch  209/1000 | Train Loss: 0.038901 | Val Loss: 0.036022
# Epoch  210/1000 | Train Loss: 0.038058 | Val Loss: 0.043122
# Epoch  211/1000 | Train Loss: 0.038976 | Val Loss: 0.038265
# Epoch  212/1000 | Train Loss: 0.039399 | Val Loss: 0.040015
# Epoch  213/1000 | Train Loss: 0.040052 | Val Loss: 0.036479
# Epoch  214/1000 | Train Loss: 0.038375 | Val Loss: 0.041273
# Epoch  215/1000 | Train Loss: 0.038589 | Val Loss: 0.037730
# Epoch  216/1000 | Train Loss: 0.039201 | Val Loss: 0.041983
# Epoch  217/1000 | Train Loss: 0.039313 | Val Loss: 0.040793
# Epoch  218/1000 | Train Loss: 0.038063 | Val Loss: 0.044678
# Epoch  219/1000 | Train Loss: 0.037800 | Val Loss: 0.039454
# Epoch  220/1000 | Train Loss: 0.041423 | Val Loss: 0.045564
# Epoch  221/1000 | Train Loss: 0.039894 | Val Loss: 0.040842
# Epoch  222/1000 | Train Loss: 0.038218 | Val Loss: 0.041649
# Epoch  223/1000 | Train Loss: 0.038225 | Val Loss: 0.036222
# Epoch  224/1000 | Train Loss: 0.039181 | Val Loss: 0.039646
# Epoch  225/1000 | Train Loss: 0.040687 | Val Loss: 0.042654
# Epoch  226/1000 | Train Loss: 0.039693 | Val Loss: 0.040506
# Epoch  227/1000 | Train Loss: 0.039935 | Val Loss: 0.044419
# Epoch  228/1000 | Train Loss: 0.038510 | Val Loss: 0.035625
# Epoch  229/1000 | Train Loss: 0.037245 | Val Loss: 0.039193
# Epoch  230/1000 | Train Loss: 0.039639 | Val Loss: 0.040972
# Epoch  231/1000 | Train Loss: 0.038358 | Val Loss: 0.039670
# Epoch  232/1000 | Train Loss: 0.039112 | Val Loss: 0.036780
# Epoch  233/1000 | Train Loss: 0.038156 | Val Loss: 0.040278
# Epoch  234/1000 | Train Loss: 0.039572 | Val Loss: 0.040908
# Epoch  235/1000 | Train Loss: 0.039126 | Val Loss: 0.040300
# Epoch  236/1000 | Train Loss: 0.038859 | Val Loss: 0.044304
# Epoch  237/1000 | Train Loss: 0.038871 | Val Loss: 0.039794
# Epoch  238/1000 | Train Loss: 0.037963 | Val Loss: 0.035791
# Epoch  239/1000 | Train Loss: 0.038555 | Val Loss: 0.039179
# Epoch  240/1000 | Train Loss: 0.037777 | Val Loss: 0.036246
# Epoch  241/1000 | Train Loss: 0.037901 | Val Loss: 0.040081
# Epoch  242/1000 | Train Loss: 0.039004 | Val Loss: 0.039672
# Epoch  243/1000 | Train Loss: 0.038936 | Val Loss: 0.037058
# Epoch  244/1000 | Train Loss: 0.038747 | Val Loss: 0.038100
# Epoch  245/1000 | Train Loss: 0.039324 | Val Loss: 0.040783
# Epoch  246/1000 | Train Loss: 0.038109 | Val Loss: 0.041724
# Epoch  247/1000 | Train Loss: 0.039645 | Val Loss: 0.039617
# Epoch  248/1000 | Train Loss: 0.038446 | Val Loss: 0.038809
# Epoch  249/1000 | Train Loss: 0.039184 | Val Loss: 0.037935
# Epoch  250/1000 | Train Loss: 0.038856 | Val Loss: 0.034963
#   New best model saved (val_loss=0.034963)
# Epoch  251/1000 | Train Loss: 0.039318 | Val Loss: 0.040645
# Epoch  252/1000 | Train Loss: 0.038483 | Val Loss: 0.040333
# Epoch  253/1000 | Train Loss: 0.037701 | Val Loss: 0.035517
# Epoch  254/1000 | Train Loss: 0.039415 | Val Loss: 0.040452
# Epoch  255/1000 | Train Loss: 0.039952 | Val Loss: 0.039988
# Epoch  256/1000 | Train Loss: 0.038267 | Val Loss: 0.042209
# Epoch  257/1000 | Train Loss: 0.039761 | Val Loss: 0.039211
# Epoch  258/1000 | Train Loss: 0.039040 | Val Loss: 0.040479
# Epoch  259/1000 | Train Loss: 0.038299 | Val Loss: 0.038696
# Epoch  260/1000 | Train Loss: 0.040575 | Val Loss: 0.040891
# Epoch  261/1000 | Train Loss: 0.037795 | Val Loss: 0.040948
# Epoch  262/1000 | Train Loss: 0.038165 | Val Loss: 0.038570
# Epoch  263/1000 | Train Loss: 0.037383 | Val Loss: 0.041003
# Epoch  264/1000 | Train Loss: 0.039268 | Val Loss: 0.038256
# Epoch  265/1000 | Train Loss: 0.039394 | Val Loss: 0.034317
#   New best model saved (val_loss=0.034317)
# Epoch  266/1000 | Train Loss: 0.037227 | Val Loss: 0.041632
# Epoch  267/1000 | Train Loss: 0.037866 | Val Loss: 0.040216
# Epoch  268/1000 | Train Loss: 0.037569 | Val Loss: 0.038853
# Epoch  269/1000 | Train Loss: 0.037487 | Val Loss: 0.038630
# Epoch  270/1000 | Train Loss: 0.038035 | Val Loss: 0.036982
# Epoch  271/1000 | Train Loss: 0.038488 | Val Loss: 0.037292
# Epoch  272/1000 | Train Loss: 0.037857 | Val Loss: 0.040897
# Epoch  273/1000 | Train Loss: 0.038853 | Val Loss: 0.043187
# Epoch  274/1000 | Train Loss: 0.039431 | Val Loss: 0.040133
# Epoch  275/1000 | Train Loss: 0.039165 | Val Loss: 0.040065
# Epoch  276/1000 | Train Loss: 0.037468 | Val Loss: 0.040051
# Epoch  277/1000 | Train Loss: 0.038278 | Val Loss: 0.039754
# Epoch  278/1000 | Train Loss: 0.037540 | Val Loss: 0.039422
# Epoch  279/1000 | Train Loss: 0.038217 | Val Loss: 0.039265
# Epoch  280/1000 | Train Loss: 0.039375 | Val Loss: 0.044647
# Epoch  281/1000 | Train Loss: 0.039255 | Val Loss: 0.037427
# Epoch  282/1000 | Train Loss: 0.037121 | Val Loss: 0.036693
# Epoch  283/1000 | Train Loss: 0.038658 | Val Loss: 0.039236
# Epoch  284/1000 | Train Loss: 0.038038 | Val Loss: 0.036899
# Epoch  285/1000 | Train Loss: 0.038052 | Val Loss: 0.040280
# Epoch  286/1000 | Train Loss: 0.038427 | Val Loss: 0.040666
# Epoch  287/1000 | Train Loss: 0.038470 | Val Loss: 0.037452
# Epoch  288/1000 | Train Loss: 0.038051 | Val Loss: 0.037482
# Epoch  289/1000 | Train Loss: 0.038803 | Val Loss: 0.040002
# Epoch  290/1000 | Train Loss: 0.039376 | Val Loss: 0.038355
# Epoch  291/1000 | Train Loss: 0.038483 | Val Loss: 0.039736
# Epoch  292/1000 | Train Loss: 0.038327 | Val Loss: 0.036804
# Epoch  293/1000 | Train Loss: 0.038381 | Val Loss: 0.041595
# Epoch  294/1000 | Train Loss: 0.039712 | Val Loss: 0.040101
# Epoch  295/1000 | Train Loss: 0.038151 | Val Loss: 0.038889
# Epoch  296/1000 | Train Loss: 0.039680 | Val Loss: 0.040423
# Epoch  297/1000 | Train Loss: 0.037771 | Val Loss: 0.039532
# Epoch  298/1000 | Train Loss: 0.039153 | Val Loss: 0.038014
# Epoch  299/1000 | Train Loss: 0.038099 | Val Loss: 0.038068
# Epoch  300/1000 | Train Loss: 0.039242 | Val Loss: 0.036509
# Epoch  301/1000 | Train Loss: 0.039576 | Val Loss: 0.041571
# Epoch  302/1000 | Train Loss: 0.038438 | Val Loss: 0.040831
# Epoch  303/1000 | Train Loss: 0.039343 | Val Loss: 0.039138
# Epoch  304/1000 | Train Loss: 0.037029 | Val Loss: 0.040972
# Epoch  305/1000 | Train Loss: 0.038651 | Val Loss: 0.039945
# Epoch  306/1000 | Train Loss: 0.038315 | Val Loss: 0.035585
# Epoch  307/1000 | Train Loss: 0.040192 | Val Loss: 0.041335
# Epoch  308/1000 | Train Loss: 0.039513 | Val Loss: 0.038350
# Epoch  309/1000 | Train Loss: 0.036929 | Val Loss: 0.038513
# Epoch  310/1000 | Train Loss: 0.037570 | Val Loss: 0.036577
# Epoch  311/1000 | Train Loss: 0.038065 | Val Loss: 0.037428
# Epoch  312/1000 | Train Loss: 0.038297 | Val Loss: 0.042749
# Epoch  313/1000 | Train Loss: 0.039746 | Val Loss: 0.035249
# Epoch  314/1000 | Train Loss: 0.039225 | Val Loss: 0.036861
# Epoch  315/1000 | Train Loss: 0.037609 | Val Loss: 0.036384
# Epoch  316/1000 | Train Loss: 0.040117 | Val Loss: 0.038368
# Epoch  317/1000 | Train Loss: 0.038201 | Val Loss: 0.036344
# Epoch  318/1000 | Train Loss: 0.039177 | Val Loss: 0.039552
# Epoch  319/1000 | Train Loss: 0.037922 | Val Loss: 0.040718
# Epoch  320/1000 | Train Loss: 0.039014 | Val Loss: 0.039680
# Epoch  321/1000 | Train Loss: 0.038417 | Val Loss: 0.039439
# Epoch  322/1000 | Train Loss: 0.036905 | Val Loss: 0.036689
# Epoch  323/1000 | Train Loss: 0.038047 | Val Loss: 0.036742
# Epoch  324/1000 | Train Loss: 0.038684 | Val Loss: 0.037713
# Epoch  325/1000 | Train Loss: 0.037953 | Val Loss: 0.041024
# Epoch  326/1000 | Train Loss: 0.037098 | Val Loss: 0.043247
# Epoch  327/1000 | Train Loss: 0.038237 | Val Loss: 0.038129
# Epoch  328/1000 | Train Loss: 0.037797 | Val Loss: 0.037444
# Epoch  329/1000 | Train Loss: 0.037599 | Val Loss: 0.036332
# Epoch  330/1000 | Train Loss: 0.037510 | Val Loss: 0.037588
# Epoch  331/1000 | Train Loss: 0.037932 | Val Loss: 0.038560
# Epoch  332/1000 | Train Loss: 0.038159 | Val Loss: 0.039054
# Epoch  333/1000 | Train Loss: 0.037390 | Val Loss: 0.038618
# Epoch  334/1000 | Train Loss: 0.039805 | Val Loss: 0.037620
# Epoch  335/1000 | Train Loss: 0.038252 | Val Loss: 0.040254
# Epoch  336/1000 | Train Loss: 0.037129 | Val Loss: 0.036852
# Epoch  337/1000 | Train Loss: 0.037386 | Val Loss: 0.035802
# Epoch  338/1000 | Train Loss: 0.037198 | Val Loss: 0.039548
# Epoch  339/1000 | Train Loss: 0.037738 | Val Loss: 0.038103
# Epoch  340/1000 | Train Loss: 0.037166 | Val Loss: 0.038832
# Epoch  341/1000 | Train Loss: 0.036545 | Val Loss: 0.038346
# Epoch  342/1000 | Train Loss: 0.038171 | Val Loss: 0.038447
# Epoch  343/1000 | Train Loss: 0.038544 | Val Loss: 0.039956
# Epoch  344/1000 | Train Loss: 0.039045 | Val Loss: 0.038089
# Epoch  345/1000 | Train Loss: 0.039067 | Val Loss: 0.040674
# Epoch  346/1000 | Train Loss: 0.039282 | Val Loss: 0.039300
# Epoch  347/1000 | Train Loss: 0.039191 | Val Loss: 0.036885
# Epoch  348/1000 | Train Loss: 0.037988 | Val Loss: 0.037848
# Epoch  349/1000 | Train Loss: 0.038885 | Val Loss: 0.033347
#   New best model saved (val_loss=0.033347)
# Epoch  350/1000 | Train Loss: 0.036716 | Val Loss: 0.034057
# Epoch  351/1000 | Train Loss: 0.037751 | Val Loss: 0.036761
# Epoch  352/1000 | Train Loss: 0.038162 | Val Loss: 0.041032
# Epoch  353/1000 | Train Loss: 0.038614 | Val Loss: 0.034049
# Epoch  354/1000 | Train Loss: 0.038934 | Val Loss: 0.040232
# Epoch  355/1000 | Train Loss: 0.038164 | Val Loss: 0.038491
# Epoch  356/1000 | Train Loss: 0.038092 | Val Loss: 0.039567
# Epoch  357/1000 | Train Loss: 0.038300 | Val Loss: 0.042966
# Epoch  358/1000 | Train Loss: 0.036983 | Val Loss: 0.039385
# Epoch  359/1000 | Train Loss: 0.039912 | Val Loss: 0.036218
# Epoch  360/1000 | Train Loss: 0.037915 | Val Loss: 0.038350
# Epoch  361/1000 | Train Loss: 0.038489 | Val Loss: 0.035812
# Epoch  362/1000 | Train Loss: 0.038030 | Val Loss: 0.041583
# Epoch  363/1000 | Train Loss: 0.039665 | Val Loss: 0.040521
# Epoch  364/1000 | Train Loss: 0.036993 | Val Loss: 0.039326
# Epoch  365/1000 | Train Loss: 0.039470 | Val Loss: 0.039855
# Epoch  366/1000 | Train Loss: 0.037561 | Val Loss: 0.036306
# Epoch  367/1000 | Train Loss: 0.039123 | Val Loss: 0.040961
# Epoch  368/1000 | Train Loss: 0.038728 | Val Loss: 0.042276
# Epoch  369/1000 | Train Loss: 0.038993 | Val Loss: 0.039459
# Epoch  370/1000 | Train Loss: 0.036692 | Val Loss: 0.037796
# Epoch  371/1000 | Train Loss: 0.037862 | Val Loss: 0.037003
# Epoch  372/1000 | Train Loss: 0.036396 | Val Loss: 0.036309
# Epoch  373/1000 | Train Loss: 0.037353 | Val Loss: 0.039811
# Epoch  374/1000 | Train Loss: 0.038242 | Val Loss: 0.034423
# Epoch  375/1000 | Train Loss: 0.038058 | Val Loss: 0.038032
# Epoch  376/1000 | Train Loss: 0.037784 | Val Loss: 0.037430
# Epoch  377/1000 | Train Loss: 0.036676 | Val Loss: 0.040702
# Epoch  378/1000 | Train Loss: 0.037451 | Val Loss: 0.037330
# Epoch  379/1000 | Train Loss: 0.037500 | Val Loss: 0.034050
# Epoch  380/1000 | Train Loss: 0.038658 | Val Loss: 0.035249
# Epoch  381/1000 | Train Loss: 0.037852 | Val Loss: 0.039054
# Epoch  382/1000 | Train Loss: 0.037449 | Val Loss: 0.040099
# Epoch  383/1000 | Train Loss: 0.036304 | Val Loss: 0.037692
# Epoch  384/1000 | Train Loss: 0.040088 | Val Loss: 0.035665
# Epoch  385/1000 | Train Loss: 0.037629 | Val Loss: 0.037941
# Epoch  386/1000 | Train Loss: 0.038709 | Val Loss: 0.039213
# Epoch  387/1000 | Train Loss: 0.037935 | Val Loss: 0.037437
# Epoch  388/1000 | Train Loss: 0.037719 | Val Loss: 0.040123
# Epoch  389/1000 | Train Loss: 0.039019 | Val Loss: 0.040227
# Epoch  390/1000 | Train Loss: 0.038084 | Val Loss: 0.037733
# Epoch  391/1000 | Train Loss: 0.038432 | Val Loss: 0.039493
# Epoch  392/1000 | Train Loss: 0.037128 | Val Loss: 0.039383
# Epoch  393/1000 | Train Loss: 0.037100 | Val Loss: 0.040281
# Epoch  394/1000 | Train Loss: 0.037715 | Val Loss: 0.039268
# Epoch  395/1000 | Train Loss: 0.038490 | Val Loss: 0.038203
# Epoch  396/1000 | Train Loss: 0.037046 | Val Loss: 0.034769
# Epoch  397/1000 | Train Loss: 0.037557 | Val Loss: 0.038990
# Epoch  398/1000 | Train Loss: 0.038460 | Val Loss: 0.036339
# Epoch  399/1000 | Train Loss: 0.037854 | Val Loss: 0.039605
# Epoch  400/1000 | Train Loss: 0.037914 | Val Loss: 0.039184
# Epoch  401/1000 | Train Loss: 0.037604 | Val Loss: 0.038263
# Epoch  402/1000 | Train Loss: 0.038158 | Val Loss: 0.038353
# Epoch  403/1000 | Train Loss: 0.039011 | Val Loss: 0.035348
# Epoch  404/1000 | Train Loss: 0.038203 | Val Loss: 0.037191
# Epoch  405/1000 | Train Loss: 0.037306 | Val Loss: 0.035546
# Epoch  406/1000 | Train Loss: 0.038492 | Val Loss: 0.036205
# Epoch  407/1000 | Train Loss: 0.036997 | Val Loss: 0.037244
# Epoch  408/1000 | Train Loss: 0.038539 | Val Loss: 0.043000
# Epoch  409/1000 | Train Loss: 0.037827 | Val Loss: 0.039664
# Epoch  410/1000 | Train Loss: 0.036966 | Val Loss: 0.038824
# Epoch  411/1000 | Train Loss: 0.038106 | Val Loss: 0.039182
# Epoch  412/1000 | Train Loss: 0.038906 | Val Loss: 0.035412
# Epoch  413/1000 | Train Loss: 0.036567 | Val Loss: 0.041393
# Epoch  414/1000 | Train Loss: 0.037705 | Val Loss: 0.040486
# Epoch  415/1000 | Train Loss: 0.038517 | Val Loss: 0.037278
# Epoch  416/1000 | Train Loss: 0.036758 | Val Loss: 0.039022
# Epoch  417/1000 | Train Loss: 0.037814 | Val Loss: 0.043633
# Epoch  418/1000 | Train Loss: 0.037458 | Val Loss: 0.037982
# Epoch  419/1000 | Train Loss: 0.037532 | Val Loss: 0.039490
# Epoch  420/1000 | Train Loss: 0.037792 | Val Loss: 0.033612
# Epoch  421/1000 | Train Loss: 0.037526 | Val Loss: 0.035943
# Epoch  422/1000 | Train Loss: 0.038684 | Val Loss: 0.036602
# Epoch  423/1000 | Train Loss: 0.037058 | Val Loss: 0.038191
# Epoch  424/1000 | Train Loss: 0.036875 | Val Loss: 0.036249
# Epoch  425/1000 | Train Loss: 0.038467 | Val Loss: 0.038855
# Epoch  426/1000 | Train Loss: 0.038311 | Val Loss: 0.040516
# Epoch  427/1000 | Train Loss: 0.036510 | Val Loss: 0.037921
# Epoch  428/1000 | Train Loss: 0.036965 | Val Loss: 0.039042
# Epoch  429/1000 | Train Loss: 0.037802 | Val Loss: 0.035494
# Epoch  430/1000 | Train Loss: 0.037851 | Val Loss: 0.039046
# Epoch  431/1000 | Train Loss: 0.037968 | Val Loss: 0.037428
# Epoch  432/1000 | Train Loss: 0.036885 | Val Loss: 0.036908
# Epoch  433/1000 | Train Loss: 0.036665 | Val Loss: 0.040957
# Epoch  434/1000 | Train Loss: 0.037332 | Val Loss: 0.034656
# Epoch  435/1000 | Train Loss: 0.038425 | Val Loss: 0.040156
# Epoch  436/1000 | Train Loss: 0.036213 | Val Loss: 0.034491
# Epoch  437/1000 | Train Loss: 0.036840 | Val Loss: 0.041749
# Epoch  438/1000 | Train Loss: 0.037035 | Val Loss: 0.039518
# Epoch  439/1000 | Train Loss: 0.037486 | Val Loss: 0.039502
# Epoch  440/1000 | Train Loss: 0.036851 | Val Loss: 0.038847
# Epoch  441/1000 | Train Loss: 0.036852 | Val Loss: 0.037491
# Epoch  442/1000 | Train Loss: 0.037863 | Val Loss: 0.041631
# Epoch  443/1000 | Train Loss: 0.038611 | Val Loss: 0.041155
# Epoch  444/1000 | Train Loss: 0.039115 | Val Loss: 0.037500
# Epoch  445/1000 | Train Loss: 0.036941 | Val Loss: 0.035996
# Epoch  446/1000 | Train Loss: 0.036777 | Val Loss: 0.036207
# Epoch  447/1000 | Train Loss: 0.038400 | Val Loss: 0.037418
# Epoch  448/1000 | Train Loss: 0.037954 | Val Loss: 0.039530
# Epoch  449/1000 | Train Loss: 0.038542 | Val Loss: 0.038755
# Epoch  450/1000 | Train Loss: 0.037757 | Val Loss: 0.036039
# Epoch  451/1000 | Train Loss: 0.037154 | Val Loss: 0.037786
# Epoch  452/1000 | Train Loss: 0.036079 | Val Loss: 0.036869
# Epoch  453/1000 | Train Loss: 0.038375 | Val Loss: 0.035388
# Epoch  454/1000 | Train Loss: 0.039755 | Val Loss: 0.037832
# Epoch  455/1000 | Train Loss: 0.037790 | Val Loss: 0.039270
# Epoch  456/1000 | Train Loss: 0.038843 | Val Loss: 0.036770
# Epoch  457/1000 | Train Loss: 0.037794 | Val Loss: 0.038385
# Epoch  458/1000 | Train Loss: 0.037457 | Val Loss: 0.037950
# Epoch  459/1000 | Train Loss: 0.037625 | Val Loss: 0.038109
# Epoch  460/1000 | Train Loss: 0.038361 | Val Loss: 0.041405
# Epoch  461/1000 | Train Loss: 0.037434 | Val Loss: 0.040514
# Epoch  462/1000 | Train Loss: 0.037407 | Val Loss: 0.036840
# Epoch  463/1000 | Train Loss: 0.038114 | Val Loss: 0.037819
# Epoch  464/1000 | Train Loss: 0.037802 | Val Loss: 0.041096
# Epoch  465/1000 | Train Loss: 0.038023 | Val Loss: 0.041611
# Epoch  466/1000 | Train Loss: 0.037711 | Val Loss: 0.040357
# Epoch  467/1000 | Train Loss: 0.039499 | Val Loss: 0.039447
# Epoch  468/1000 | Train Loss: 0.037271 | Val Loss: 0.044894
# Epoch  469/1000 | Train Loss: 0.038790 | Val Loss: 0.040935
# Epoch  470/1000 | Train Loss: 0.037128 | Val Loss: 0.039661
# Epoch  471/1000 | Train Loss: 0.037525 | Val Loss: 0.040824
# Epoch  472/1000 | Train Loss: 0.037351 | Val Loss: 0.040345
# Epoch  473/1000 | Train Loss: 0.037176 | Val Loss: 0.037143
# Epoch  474/1000 | Train Loss: 0.037736 | Val Loss: 0.038113
# Epoch  475/1000 | Train Loss: 0.039000 | Val Loss: 0.036610
# Epoch  476/1000 | Train Loss: 0.038766 | Val Loss: 0.035565
# Epoch  477/1000 | Train Loss: 0.037295 | Val Loss: 0.038881
# Epoch  478/1000 | Train Loss: 0.036244 | Val Loss: 0.039103
# Epoch  479/1000 | Train Loss: 0.036891 | Val Loss: 0.038338
# Epoch  480/1000 | Train Loss: 0.037637 | Val Loss: 0.036721
# Epoch  481/1000 | Train Loss: 0.038993 | Val Loss: 0.034884
# Epoch  482/1000 | Train Loss: 0.037210 | Val Loss: 0.034980
# Epoch  483/1000 | Train Loss: 0.037881 | Val Loss: 0.035044
# Epoch  484/1000 | Train Loss: 0.037778 | Val Loss: 0.037852
# Epoch  485/1000 | Train Loss: 0.038452 | Val Loss: 0.038611
# Epoch  486/1000 | Train Loss: 0.038347 | Val Loss: 0.035531
# Epoch  487/1000 | Train Loss: 0.036533 | Val Loss: 0.038869
# Epoch  488/1000 | Train Loss: 0.037690 | Val Loss: 0.040593
# Epoch  489/1000 | Train Loss: 0.037691 | Val Loss: 0.037191
# Epoch  490/1000 | Train Loss: 0.036393 | Val Loss: 0.037633
# Epoch  491/1000 | Train Loss: 0.038868 | Val Loss: 0.032674
#   New best model saved (val_loss=0.032674)
# Epoch  492/1000 | Train Loss: 0.037798 | Val Loss: 0.037596
# Epoch  493/1000 | Train Loss: 0.036802 | Val Loss: 0.041248
# Epoch  494/1000 | Train Loss: 0.037016 | Val Loss: 0.038909
# Epoch  495/1000 | Train Loss: 0.036422 | Val Loss: 0.038970
# Epoch  496/1000 | Train Loss: 0.038610 | Val Loss: 0.033878
# Epoch  497/1000 | Train Loss: 0.038091 | Val Loss: 0.036589
# Epoch  498/1000 | Train Loss: 0.037081 | Val Loss: 0.038099
# Epoch  499/1000 | Train Loss: 0.036879 | Val Loss: 0.038146
# Epoch  500/1000 | Train Loss: 0.036309 | Val Loss: 0.036587
# Epoch  501/1000 | Train Loss: 0.037522 | Val Loss: 0.037751
# Epoch  502/1000 | Train Loss: 0.036611 | Val Loss: 0.035764
# Epoch  503/1000 | Train Loss: 0.037024 | Val Loss: 0.039363
# Epoch  504/1000 | Train Loss: 0.037295 | Val Loss: 0.038875
# Epoch  505/1000 | Train Loss: 0.037238 | Val Loss: 0.034653
# Epoch  506/1000 | Train Loss: 0.037473 | Val Loss: 0.036086
# Epoch  507/1000 | Train Loss: 0.038811 | Val Loss: 0.035501
# Epoch  508/1000 | Train Loss: 0.037580 | Val Loss: 0.032078
#   New best model saved (val_loss=0.032078)
# Epoch  509/1000 | Train Loss: 0.037950 | Val Loss: 0.037705
# Epoch  510/1000 | Train Loss: 0.037027 | Val Loss: 0.035624
# Epoch  511/1000 | Train Loss: 0.038585 | Val Loss: 0.038609
# Epoch  512/1000 | Train Loss: 0.037506 | Val Loss: 0.036835
# Epoch  513/1000 | Train Loss: 0.037781 | Val Loss: 0.036957
# Epoch  514/1000 | Train Loss: 0.037939 | Val Loss: 0.037399
# Epoch  515/1000 | Train Loss: 0.038588 | Val Loss: 0.037798
# Epoch  516/1000 | Train Loss: 0.037361 | Val Loss: 0.037907
# Epoch  517/1000 | Train Loss: 0.036952 | Val Loss: 0.039253
# Epoch  518/1000 | Train Loss: 0.038531 | Val Loss: 0.038722
# Epoch  519/1000 | Train Loss: 0.037893 | Val Loss: 0.038461
# Epoch  520/1000 | Train Loss: 0.039078 | Val Loss: 0.037663
# Epoch  521/1000 | Train Loss: 0.038602 | Val Loss: 0.038487
# Epoch  522/1000 | Train Loss: 0.036865 | Val Loss: 0.036307
# Epoch  523/1000 | Train Loss: 0.037957 | Val Loss: 0.038251
# Epoch  524/1000 | Train Loss: 0.037152 | Val Loss: 0.035325
# Epoch  525/1000 | Train Loss: 0.037685 | Val Loss: 0.038093
# Epoch  526/1000 | Train Loss: 0.038124 | Val Loss: 0.039799
# Epoch  527/1000 | Train Loss: 0.037398 | Val Loss: 0.036711
# Epoch  528/1000 | Train Loss: 0.037601 | Val Loss: 0.040392
# Epoch  529/1000 | Train Loss: 0.036939 | Val Loss: 0.039527
# Epoch  530/1000 | Train Loss: 0.037251 | Val Loss: 0.034606
# Epoch  531/1000 | Train Loss: 0.036422 | Val Loss: 0.038220
# Epoch  532/1000 | Train Loss: 0.037682 | Val Loss: 0.036416
# Epoch  533/1000 | Train Loss: 0.037425 | Val Loss: 0.041474
# Epoch  534/1000 | Train Loss: 0.037565 | Val Loss: 0.035741
# Epoch  535/1000 | Train Loss: 0.036957 | Val Loss: 0.035516
# Epoch  536/1000 | Train Loss: 0.036951 | Val Loss: 0.040911
# Epoch  537/1000 | Train Loss: 0.037337 | Val Loss: 0.036394
# Epoch  538/1000 | Train Loss: 0.036804 | Val Loss: 0.040404
# Epoch  539/1000 | Train Loss: 0.037218 | Val Loss: 0.033945
# Epoch  540/1000 | Train Loss: 0.036237 | Val Loss: 0.036796
# Epoch  541/1000 | Train Loss: 0.035360 | Val Loss: 0.038513
# Epoch  542/1000 | Train Loss: 0.038359 | Val Loss: 0.043049
# Epoch  543/1000 | Train Loss: 0.039204 | Val Loss: 0.036532
# Epoch  544/1000 | Train Loss: 0.037602 | Val Loss: 0.037795
# Epoch  545/1000 | Train Loss: 0.036436 | Val Loss: 0.037609
# Epoch  546/1000 | Train Loss: 0.037412 | Val Loss: 0.037426
# Epoch  547/1000 | Train Loss: 0.038952 | Val Loss: 0.033499
# Epoch  548/1000 | Train Loss: 0.035819 | Val Loss: 0.038657
# Epoch  549/1000 | Train Loss: 0.037856 | Val Loss: 0.040369
# Epoch  550/1000 | Train Loss: 0.037150 | Val Loss: 0.035356
# Epoch  551/1000 | Train Loss: 0.038287 | Val Loss: 0.039536
# Epoch  552/1000 | Train Loss: 0.038318 | Val Loss: 0.037126
# Epoch  553/1000 | Train Loss: 0.037376 | Val Loss: 0.037104
# Epoch  554/1000 | Train Loss: 0.037416 | Val Loss: 0.035116
# Epoch  555/1000 | Train Loss: 0.038484 | Val Loss: 0.040294
# Epoch  556/1000 | Train Loss: 0.038087 | Val Loss: 0.034687
# Epoch  557/1000 | Train Loss: 0.036656 | Val Loss: 0.035090
# Epoch  558/1000 | Train Loss: 0.036903 | Val Loss: 0.038630
# Epoch  559/1000 | Train Loss: 0.037619 | Val Loss: 0.037455
# Epoch  560/1000 | Train Loss: 0.038072 | Val Loss: 0.036798
# Epoch  561/1000 | Train Loss: 0.037790 | Val Loss: 0.039880
# Epoch  562/1000 | Train Loss: 0.038541 | Val Loss: 0.036212
# Epoch  563/1000 | Train Loss: 0.036814 | Val Loss: 0.041366
# Epoch  564/1000 | Train Loss: 0.037022 | Val Loss: 0.039014
# Epoch  565/1000 | Train Loss: 0.036818 | Val Loss: 0.037262
# Epoch  566/1000 | Train Loss: 0.036580 | Val Loss: 0.038108
# Epoch  567/1000 | Train Loss: 0.037137 | Val Loss: 0.040170
# Epoch  568/1000 | Train Loss: 0.037816 | Val Loss: 0.039322
# Epoch  569/1000 | Train Loss: 0.037035 | Val Loss: 0.036768
# Epoch  570/1000 | Train Loss: 0.037121 | Val Loss: 0.036874
# Epoch  571/1000 | Train Loss: 0.035434 | Val Loss: 0.038282
# Epoch  572/1000 | Train Loss: 0.037981 | Val Loss: 0.037991
# Epoch  573/1000 | Train Loss: 0.037615 | Val Loss: 0.037632
# Epoch  574/1000 | Train Loss: 0.036749 | Val Loss: 0.039228
# Epoch  575/1000 | Train Loss: 0.037639 | Val Loss: 0.040424
# Epoch  576/1000 | Train Loss: 0.037591 | Val Loss: 0.032168
# Epoch  577/1000 | Train Loss: 0.037412 | Val Loss: 0.038052
# Epoch  578/1000 | Train Loss: 0.037332 | Val Loss: 0.035228
# Epoch  579/1000 | Train Loss: 0.039209 | Val Loss: 0.037879
# Epoch  580/1000 | Train Loss: 0.037315 | Val Loss: 0.038497
# Epoch  581/1000 | Train Loss: 0.039015 | Val Loss: 0.036677
# Epoch  582/1000 | Train Loss: 0.037570 | Val Loss: 0.041315
# Epoch  583/1000 | Train Loss: 0.036479 | Val Loss: 0.040460
# Epoch  584/1000 | Train Loss: 0.037736 | Val Loss: 0.039219
# Epoch  585/1000 | Train Loss: 0.037756 | Val Loss: 0.035583
# Epoch  586/1000 | Train Loss: 0.037948 | Val Loss: 0.038786
# Epoch  587/1000 | Train Loss: 0.036629 | Val Loss: 0.037437
# Epoch  588/1000 | Train Loss: 0.038782 | Val Loss: 0.037354
# Epoch  589/1000 | Train Loss: 0.036592 | Val Loss: 0.036375
# Epoch  590/1000 | Train Loss: 0.037360 | Val Loss: 0.035507
# Epoch  591/1000 | Train Loss: 0.036554 | Val Loss: 0.037108
# Epoch  592/1000 | Train Loss: 0.037263 | Val Loss: 0.039908
# Epoch  593/1000 | Train Loss: 0.037844 | Val Loss: 0.041295
# Epoch  594/1000 | Train Loss: 0.037196 | Val Loss: 0.038187
# Epoch  595/1000 | Train Loss: 0.037106 | Val Loss: 0.036537
# Epoch  596/1000 | Train Loss: 0.037111 | Val Loss: 0.041829
# Epoch  597/1000 | Train Loss: 0.037745 | Val Loss: 0.036642
# Epoch  598/1000 | Train Loss: 0.037378 | Val Loss: 0.037431
# Epoch  599/1000 | Train Loss: 0.037907 | Val Loss: 0.036873
# Epoch  600/1000 | Train Loss: 0.037500 | Val Loss: 0.039400
# Epoch  601/1000 | Train Loss: 0.040106 | Val Loss: 0.038849
# Epoch  602/1000 | Train Loss: 0.039007 | Val Loss: 0.035232
# Epoch  603/1000 | Train Loss: 0.036256 | Val Loss: 0.040242
# Epoch  604/1000 | Train Loss: 0.036489 | Val Loss: 0.039804
# Epoch  605/1000 | Train Loss: 0.037528 | Val Loss: 0.033746
# Epoch  606/1000 | Train Loss: 0.036036 | Val Loss: 0.035726
# Epoch  607/1000 | Train Loss: 0.036637 | Val Loss: 0.040161
# Epoch  608/1000 | Train Loss: 0.037507 | Val Loss: 0.037904
# Epoch  609/1000 | Train Loss: 0.037996 | Val Loss: 0.039406
# Epoch  610/1000 | Train Loss: 0.037517 | Val Loss: 0.038462
# Epoch  611/1000 | Train Loss: 0.036514 | Val Loss: 0.036334
# Epoch  612/1000 | Train Loss: 0.037574 | Val Loss: 0.035310
# Epoch  613/1000 | Train Loss: 0.037184 | Val Loss: 0.041778
# Epoch  614/1000 | Train Loss: 0.037100 | Val Loss: 0.034681
# Epoch  615/1000 | Train Loss: 0.036490 | Val Loss: 0.037368
# Epoch  616/1000 | Train Loss: 0.036897 | Val Loss: 0.039917
# Epoch  617/1000 | Train Loss: 0.038219 | Val Loss: 0.041698
# Epoch  618/1000 | Train Loss: 0.036701 | Val Loss: 0.040289
# Epoch  619/1000 | Train Loss: 0.036509 | Val Loss: 0.036062
# Epoch  620/1000 | Train Loss: 0.037062 | Val Loss: 0.037144
# Epoch  621/1000 | Train Loss: 0.036901 | Val Loss: 0.039294
# Epoch  622/1000 | Train Loss: 0.038437 | Val Loss: 0.040958
# Epoch  623/1000 | Train Loss: 0.037143 | Val Loss: 0.034252
# Epoch  624/1000 | Train Loss: 0.037407 | Val Loss: 0.038831
# Epoch  625/1000 | Train Loss: 0.037904 | Val Loss: 0.036437
# Epoch  626/1000 | Train Loss: 0.038815 | Val Loss: 0.038346
# Epoch  627/1000 | Train Loss: 0.038166 | Val Loss: 0.041042
# Epoch  628/1000 | Train Loss: 0.038188 | Val Loss: 0.040530
# Epoch  629/1000 | Train Loss: 0.038429 | Val Loss: 0.039477
# Epoch  630/1000 | Train Loss: 0.036689 | Val Loss: 0.037438
# Epoch  631/1000 | Train Loss: 0.037858 | Val Loss: 0.037791
# Epoch  632/1000 | Train Loss: 0.036906 | Val Loss: 0.038159
# Epoch  633/1000 | Train Loss: 0.038443 | Val Loss: 0.038714
# Epoch  634/1000 | Train Loss: 0.036946 | Val Loss: 0.037197
# Epoch  635/1000 | Train Loss: 0.037640 | Val Loss: 0.037180
# Epoch  636/1000 | Train Loss: 0.037152 | Val Loss: 0.034283
# Epoch  637/1000 | Train Loss: 0.037084 | Val Loss: 0.034342
# Epoch  638/1000 | Train Loss: 0.036562 | Val Loss: 0.035504
# Epoch  639/1000 | Train Loss: 0.037659 | Val Loss: 0.033906
# Epoch  640/1000 | Train Loss: 0.038789 | Val Loss: 0.041105
# Epoch  641/1000 | Train Loss: 0.035589 | Val Loss: 0.035656
# Epoch  642/1000 | Train Loss: 0.036396 | Val Loss: 0.035256
# Epoch  643/1000 | Train Loss: 0.037081 | Val Loss: 0.036024
# Epoch  644/1000 | Train Loss: 0.036545 | Val Loss: 0.037731
# Epoch  645/1000 | Train Loss: 0.036320 | Val Loss: 0.038485
# Epoch  646/1000 | Train Loss: 0.037990 | Val Loss: 0.037377
# Epoch  647/1000 | Train Loss: 0.036482 | Val Loss: 0.037184
# Epoch  648/1000 | Train Loss: 0.036804 | Val Loss: 0.039861
# Epoch  649/1000 | Train Loss: 0.036785 | Val Loss: 0.038492
# Epoch  650/1000 | Train Loss: 0.037786 | Val Loss: 0.036559
# Epoch  651/1000 | Train Loss: 0.037543 | Val Loss: 0.035983
# Epoch  652/1000 | Train Loss: 0.036937 | Val Loss: 0.036274
# Epoch  653/1000 | Train Loss: 0.037610 | Val Loss: 0.035585
# Epoch  654/1000 | Train Loss: 0.037705 | Val Loss: 0.040240
# Epoch  655/1000 | Train Loss: 0.037454 | Val Loss: 0.038505
# Epoch  656/1000 | Train Loss: 0.037242 | Val Loss: 0.034320
# Epoch  657/1000 | Train Loss: 0.037943 | Val Loss: 0.041945
# Epoch  658/1000 | Train Loss: 0.037050 | Val Loss: 0.038873
# Epoch  659/1000 | Train Loss: 0.038263 | Val Loss: 0.039060
# Epoch  660/1000 | Train Loss: 0.035931 | Val Loss: 0.038246
# Epoch  661/1000 | Train Loss: 0.035842 | Val Loss: 0.034944
# Epoch  662/1000 | Train Loss: 0.036386 | Val Loss: 0.035132
# Epoch  663/1000 | Train Loss: 0.037231 | Val Loss: 0.041632
# Epoch  664/1000 | Train Loss: 0.038072 | Val Loss: 0.035716
# Epoch  665/1000 | Train Loss: 0.036087 | Val Loss: 0.037860
# Epoch  666/1000 | Train Loss: 0.036865 | Val Loss: 0.032962
# Epoch  667/1000 | Train Loss: 0.035857 | Val Loss: 0.036690
# Epoch  668/1000 | Train Loss: 0.036536 | Val Loss: 0.039959
# Epoch  669/1000 | Train Loss: 0.036714 | Val Loss: 0.036518
# Epoch  670/1000 | Train Loss: 0.036618 | Val Loss: 0.039245
# Epoch  671/1000 | Train Loss: 0.037390 | Val Loss: 0.039563
# Epoch  672/1000 | Train Loss: 0.036759 | Val Loss: 0.038941
# Epoch  673/1000 | Train Loss: 0.037001 | Val Loss: 0.040804
# Epoch  674/1000 | Train Loss: 0.036434 | Val Loss: 0.034739
# Epoch  675/1000 | Train Loss: 0.036126 | Val Loss: 0.033880
# Epoch  676/1000 | Train Loss: 0.037081 | Val Loss: 0.041798
# Epoch  677/1000 | Train Loss: 0.038129 | Val Loss: 0.038538
# Epoch  678/1000 | Train Loss: 0.037170 | Val Loss: 0.036278
# Epoch  679/1000 | Train Loss: 0.038070 | Val Loss: 0.033416
# Epoch  680/1000 | Train Loss: 0.037009 | Val Loss: 0.037755
# Epoch  681/1000 | Train Loss: 0.036884 | Val Loss: 0.035117
# Epoch  682/1000 | Train Loss: 0.037571 | Val Loss: 0.036787
# Epoch  683/1000 | Train Loss: 0.036199 | Val Loss: 0.038208
# Epoch  684/1000 | Train Loss: 0.036657 | Val Loss: 0.040547
# Epoch  685/1000 | Train Loss: 0.036195 | Val Loss: 0.036344
# Epoch  686/1000 | Train Loss: 0.036933 | Val Loss: 0.035563
# Epoch  687/1000 | Train Loss: 0.036758 | Val Loss: 0.036232
# Epoch  688/1000 | Train Loss: 0.039230 | Val Loss: 0.042033
# Epoch  689/1000 | Train Loss: 0.036682 | Val Loss: 0.041282
# Epoch  690/1000 | Train Loss: 0.038002 | Val Loss: 0.037693
# Epoch  691/1000 | Train Loss: 0.035542 | Val Loss: 0.039715
# Epoch  692/1000 | Train Loss: 0.036875 | Val Loss: 0.037609
# Epoch  693/1000 | Train Loss: 0.036695 | Val Loss: 0.038354
# Epoch  694/1000 | Train Loss: 0.038123 | Val Loss: 0.039437
# Epoch  695/1000 | Train Loss: 0.036771 | Val Loss: 0.040382
# Epoch  696/1000 | Train Loss: 0.036013 | Val Loss: 0.037321
# Epoch  697/1000 | Train Loss: 0.036167 | Val Loss: 0.035613
# Epoch  698/1000 | Train Loss: 0.037256 | Val Loss: 0.033672
# Epoch  699/1000 | Train Loss: 0.036623 | Val Loss: 0.035041
# Epoch  700/1000 | Train Loss: 0.036060 | Val Loss: 0.035775
# Epoch  701/1000 | Train Loss: 0.036886 | Val Loss: 0.036695
# Epoch  702/1000 | Train Loss: 0.037180 | Val Loss: 0.035512
# Epoch  703/1000 | Train Loss: 0.036774 | Val Loss: 0.037759
# Epoch  704/1000 | Train Loss: 0.037190 | Val Loss: 0.037034
# Epoch  705/1000 | Train Loss: 0.037214 | Val Loss: 0.039368
# Epoch  706/1000 | Train Loss: 0.036858 | Val Loss: 0.037949
# Epoch  707/1000 | Train Loss: 0.036628 | Val Loss: 0.037097
# Epoch  708/1000 | Train Loss: 0.036994 | Val Loss: 0.035077
# Epoch  709/1000 | Train Loss: 0.036892 | Val Loss: 0.042225
# Epoch  710/1000 | Train Loss: 0.037315 | Val Loss: 0.035388
# Epoch  711/1000 | Train Loss: 0.036872 | Val Loss: 0.035610
# Epoch  712/1000 | Train Loss: 0.036702 | Val Loss: 0.042461
# Epoch  713/1000 | Train Loss: 0.038099 | Val Loss: 0.040556
# Epoch  714/1000 | Train Loss: 0.036121 | Val Loss: 0.035803
# Epoch  715/1000 | Train Loss: 0.038172 | Val Loss: 0.036186
# Epoch  716/1000 | Train Loss: 0.036650 | Val Loss: 0.037288
# Epoch  717/1000 | Train Loss: 0.036340 | Val Loss: 0.039531
# Epoch  718/1000 | Train Loss: 0.036657 | Val Loss: 0.039423
# Epoch  719/1000 | Train Loss: 0.036704 | Val Loss: 0.041593
# Epoch  720/1000 | Train Loss: 0.037458 | Val Loss: 0.040570
# Epoch  721/1000 | Train Loss: 0.036050 | Val Loss: 0.034997
# Epoch  722/1000 | Train Loss: 0.038104 | Val Loss: 0.039574
# Epoch  723/1000 | Train Loss: 0.037302 | Val Loss: 0.032745
# Epoch  724/1000 | Train Loss: 0.038082 | Val Loss: 0.036532
# Epoch  725/1000 | Train Loss: 0.036596 | Val Loss: 0.035363
# Epoch  726/1000 | Train Loss: 0.037103 | Val Loss: 0.035272
# Epoch  727/1000 | Train Loss: 0.036490 | Val Loss: 0.036542
# Epoch  728/1000 | Train Loss: 0.036898 | Val Loss: 0.041699
# Epoch  729/1000 | Train Loss: 0.037773 | Val Loss: 0.036668
# Epoch  730/1000 | Train Loss: 0.037014 | Val Loss: 0.037767
# Epoch  731/1000 | Train Loss: 0.036461 | Val Loss: 0.041940
# Epoch  732/1000 | Train Loss: 0.037439 | Val Loss: 0.039254
# Epoch  733/1000 | Train Loss: 0.037925 | Val Loss: 0.041563
# Epoch  734/1000 | Train Loss: 0.037478 | Val Loss: 0.038031
# Epoch  735/1000 | Train Loss: 0.036121 | Val Loss: 0.036336
# Epoch  736/1000 | Train Loss: 0.036340 | Val Loss: 0.038414
# Epoch  737/1000 | Train Loss: 0.036235 | Val Loss: 0.037399
# Epoch  738/1000 | Train Loss: 0.037234 | Val Loss: 0.039150
# Epoch  739/1000 | Train Loss: 0.037204 | Val Loss: 0.039860
# Epoch  740/1000 | Train Loss: 0.036615 | Val Loss: 0.038590
# Epoch  741/1000 | Train Loss: 0.038672 | Val Loss: 0.036473
# Epoch  742/1000 | Train Loss: 0.036472 | Val Loss: 0.036264
# Epoch  743/1000 | Train Loss: 0.037674 | Val Loss: 0.035649
# Epoch  744/1000 | Train Loss: 0.036456 | Val Loss: 0.036290
# Epoch  745/1000 | Train Loss: 0.038311 | Val Loss: 0.036037
# Epoch  746/1000 | Train Loss: 0.036774 | Val Loss: 0.034996
# Epoch  747/1000 | Train Loss: 0.037722 | Val Loss: 0.034068
# Epoch  748/1000 | Train Loss: 0.038235 | Val Loss: 0.038855
# Epoch  749/1000 | Train Loss: 0.036886 | Val Loss: 0.041049
# Epoch  750/1000 | Train Loss: 0.037181 | Val Loss: 0.034536
# Epoch  751/1000 | Train Loss: 0.037087 | Val Loss: 0.035665
# Epoch  752/1000 | Train Loss: 0.036871 | Val Loss: 0.039790
# Epoch  753/1000 | Train Loss: 0.036171 | Val Loss: 0.037839
# Epoch  754/1000 | Train Loss: 0.037662 | Val Loss: 0.037989
# Epoch  755/1000 | Train Loss: 0.036783 | Val Loss: 0.035169
# Epoch  756/1000 | Train Loss: 0.037597 | Val Loss: 0.035813
# Epoch  757/1000 | Train Loss: 0.035691 | Val Loss: 0.035445
# Epoch  758/1000 | Train Loss: 0.037148 | Val Loss: 0.037286
# Epoch  759/1000 | Train Loss: 0.037443 | Val Loss: 0.036856
# Epoch  760/1000 | Train Loss: 0.037368 | Val Loss: 0.035256
# Epoch  761/1000 | Train Loss: 0.037154 | Val Loss: 0.036897
# Epoch  762/1000 | Train Loss: 0.037529 | Val Loss: 0.036579
# Epoch  763/1000 | Train Loss: 0.036980 | Val Loss: 0.038212
# Epoch  764/1000 | Train Loss: 0.035978 | Val Loss: 0.036470
# Epoch  765/1000 | Train Loss: 0.036764 | Val Loss: 0.038247
# Epoch  766/1000 | Train Loss: 0.035812 | Val Loss: 0.037047
# Epoch  767/1000 | Train Loss: 0.036389 | Val Loss: 0.038585
# Epoch  768/1000 | Train Loss: 0.037585 | Val Loss: 0.037193
# Epoch  769/1000 | Train Loss: 0.037275 | Val Loss: 0.033946
# Epoch  770/1000 | Train Loss: 0.037026 | Val Loss: 0.038160
# Epoch  771/1000 | Train Loss: 0.037402 | Val Loss: 0.034491
# Epoch  772/1000 | Train Loss: 0.037279 | Val Loss: 0.038236
# Epoch  773/1000 | Train Loss: 0.037811 | Val Loss: 0.040932
# Epoch  774/1000 | Train Loss: 0.037555 | Val Loss: 0.034750
# Epoch  775/1000 | Train Loss: 0.036613 | Val Loss: 0.036242
# Epoch  776/1000 | Train Loss: 0.037005 | Val Loss: 0.041021
# Epoch  777/1000 | Train Loss: 0.036752 | Val Loss: 0.036913
# Epoch  778/1000 | Train Loss: 0.037260 | Val Loss: 0.035766
# Epoch  779/1000 | Train Loss: 0.037254 | Val Loss: 0.037751
# Epoch  780/1000 | Train Loss: 0.036870 | Val Loss: 0.034678
# Epoch  781/1000 | Train Loss: 0.037797 | Val Loss: 0.035062
# Epoch  782/1000 | Train Loss: 0.037205 | Val Loss: 0.037965
# Epoch  783/1000 | Train Loss: 0.038302 | Val Loss: 0.036507
# Epoch  784/1000 | Train Loss: 0.037709 | Val Loss: 0.036421
# Epoch  785/1000 | Train Loss: 0.036089 | Val Loss: 0.033282
# Epoch  786/1000 | Train Loss: 0.036206 | Val Loss: 0.034012
# Epoch  787/1000 | Train Loss: 0.036843 | Val Loss: 0.036005
# Epoch  788/1000 | Train Loss: 0.037837 | Val Loss: 0.039100
# Epoch  789/1000 | Train Loss: 0.036189 | Val Loss: 0.037429
# Epoch  790/1000 | Train Loss: 0.037163 | Val Loss: 0.039012
# Epoch  791/1000 | Train Loss: 0.037121 | Val Loss: 0.041562
# Epoch  792/1000 | Train Loss: 0.039331 | Val Loss: 0.034722
# Epoch  793/1000 | Train Loss: 0.037852 | Val Loss: 0.037018
# Epoch  794/1000 | Train Loss: 0.036263 | Val Loss: 0.037456
# Epoch  795/1000 | Train Loss: 0.035913 | Val Loss: 0.035324
# Epoch  796/1000 | Train Loss: 0.038097 | Val Loss: 0.035750
# Epoch  797/1000 | Train Loss: 0.035894 | Val Loss: 0.035133
# Epoch  798/1000 | Train Loss: 0.036692 | Val Loss: 0.035569
# Epoch  799/1000 | Train Loss: 0.037044 | Val Loss: 0.036221
# Epoch  800/1000 | Train Loss: 0.036138 | Val Loss: 0.036780
# Epoch  801/1000 | Train Loss: 0.036441 | Val Loss: 0.037470
# Epoch  802/1000 | Train Loss: 0.037108 | Val Loss: 0.040748
# Epoch  803/1000 | Train Loss: 0.035820 | Val Loss: 0.036379
# Epoch  804/1000 | Train Loss: 0.037664 | Val Loss: 0.039733
# Epoch  805/1000 | Train Loss: 0.037051 | Val Loss: 0.039590
# Epoch  806/1000 | Train Loss: 0.037300 | Val Loss: 0.038097
# Epoch  807/1000 | Train Loss: 0.036154 | Val Loss: 0.039015
# Epoch  808/1000 | Train Loss: 0.036630 | Val Loss: 0.038323
# Epoch  809/1000 | Train Loss: 0.037326 | Val Loss: 0.036894
# Epoch  810/1000 | Train Loss: 0.036747 | Val Loss: 0.038910
# Epoch  811/1000 | Train Loss: 0.037097 | Val Loss: 0.038804
# Epoch  812/1000 | Train Loss: 0.036554 | Val Loss: 0.037269
# Epoch  813/1000 | Train Loss: 0.038243 | Val Loss: 0.036671
# Epoch  814/1000 | Train Loss: 0.037148 | Val Loss: 0.034590
# Epoch  815/1000 | Train Loss: 0.036378 | Val Loss: 0.038297
# Epoch  816/1000 | Train Loss: 0.037666 | Val Loss: 0.038823
# Epoch  817/1000 | Train Loss: 0.037148 | Val Loss: 0.039789
# Epoch  818/1000 | Train Loss: 0.037005 | Val Loss: 0.037118
# Epoch  819/1000 | Train Loss: 0.037994 | Val Loss: 0.042964
# Epoch  820/1000 | Train Loss: 0.036551 | Val Loss: 0.035293
# Epoch  821/1000 | Train Loss: 0.037283 | Val Loss: 0.040537
# Epoch  822/1000 | Train Loss: 0.037510 | Val Loss: 0.039480
# Epoch  823/1000 | Train Loss: 0.036501 | Val Loss: 0.038378
# Epoch  824/1000 | Train Loss: 0.037473 | Val Loss: 0.036924
# Epoch  825/1000 | Train Loss: 0.035308 | Val Loss: 0.034625
# Epoch  826/1000 | Train Loss: 0.035362 | Val Loss: 0.038302
# Epoch  827/1000 | Train Loss: 0.037139 | Val Loss: 0.036735
# Epoch  828/1000 | Train Loss: 0.036907 | Val Loss: 0.037475
# Epoch  829/1000 | Train Loss: 0.035883 | Val Loss: 0.035841
# Epoch  830/1000 | Train Loss: 0.036308 | Val Loss: 0.039923
# Epoch  831/1000 | Train Loss: 0.036005 | Val Loss: 0.035152
# Epoch  832/1000 | Train Loss: 0.036598 | Val Loss: 0.037925
# Epoch  833/1000 | Train Loss: 0.037860 | Val Loss: 0.036816
# Epoch  834/1000 | Train Loss: 0.038133 | Val Loss: 0.036761
# Epoch  835/1000 | Train Loss: 0.037342 | Val Loss: 0.036436
# Epoch  836/1000 | Train Loss: 0.036996 | Val Loss: 0.035702
# Epoch  837/1000 | Train Loss: 0.037150 | Val Loss: 0.038135
# Epoch  838/1000 | Train Loss: 0.035950 | Val Loss: 0.037372
# Epoch  839/1000 | Train Loss: 0.036902 | Val Loss: 0.036948
# Epoch  840/1000 | Train Loss: 0.036213 | Val Loss: 0.036378
# Epoch  841/1000 | Train Loss: 0.037470 | Val Loss: 0.037960
# Epoch  842/1000 | Train Loss: 0.037199 | Val Loss: 0.035253
# Epoch  843/1000 | Train Loss: 0.037368 | Val Loss: 0.036579
# Epoch  844/1000 | Train Loss: 0.037522 | Val Loss: 0.042006
# Epoch  845/1000 | Train Loss: 0.037248 | Val Loss: 0.041931
# Epoch  846/1000 | Train Loss: 0.037144 | Val Loss: 0.038752
# Epoch  847/1000 | Train Loss: 0.039096 | Val Loss: 0.036308
# Epoch  848/1000 | Train Loss: 0.037505 | Val Loss: 0.036895
# Epoch  849/1000 | Train Loss: 0.035728 | Val Loss: 0.036075
# Epoch  850/1000 | Train Loss: 0.036635 | Val Loss: 0.038573
# Epoch  851/1000 | Train Loss: 0.035327 | Val Loss: 0.040884
# Epoch  852/1000 | Train Loss: 0.037189 | Val Loss: 0.037486
# Epoch  853/1000 | Train Loss: 0.037632 | Val Loss: 0.037711
# Epoch  854/1000 | Train Loss: 0.036582 | Val Loss: 0.040551
# Epoch  855/1000 | Train Loss: 0.037471 | Val Loss: 0.038655
# Epoch  856/1000 | Train Loss: 0.037080 | Val Loss: 0.035306
# Epoch  857/1000 | Train Loss: 0.037272 | Val Loss: 0.036293
# Epoch  858/1000 | Train Loss: 0.038394 | Val Loss: 0.036824
# Epoch  859/1000 | Train Loss: 0.037714 | Val Loss: 0.038548
# Epoch  860/1000 | Train Loss: 0.036783 | Val Loss: 0.035304
# Epoch  861/1000 | Train Loss: 0.036744 | Val Loss: 0.033193
# Epoch  862/1000 | Train Loss: 0.035305 | Val Loss: 0.036920
# Epoch  863/1000 | Train Loss: 0.038005 | Val Loss: 0.037632
# Epoch  864/1000 | Train Loss: 0.037049 | Val Loss: 0.036518
# Epoch  865/1000 | Train Loss: 0.037920 | Val Loss: 0.036271
# Epoch  866/1000 | Train Loss: 0.036851 | Val Loss: 0.037575
# Epoch  867/1000 | Train Loss: 0.036058 | Val Loss: 0.036186
# Epoch  868/1000 | Train Loss: 0.038469 | Val Loss: 0.038231
# Epoch  869/1000 | Train Loss: 0.037419 | Val Loss: 0.036135
# Epoch  870/1000 | Train Loss: 0.038161 | Val Loss: 0.036883
# Epoch  871/1000 | Train Loss: 0.036656 | Val Loss: 0.034028
# Epoch  872/1000 | Train Loss: 0.037421 | Val Loss: 0.034720
# Epoch  873/1000 | Train Loss: 0.036815 | Val Loss: 0.034091
# Epoch  874/1000 | Train Loss: 0.037149 | Val Loss: 0.037352
# Epoch  875/1000 | Train Loss: 0.037195 | Val Loss: 0.032944
# Epoch  876/1000 | Train Loss: 0.036627 | Val Loss: 0.034321
# Epoch  877/1000 | Train Loss: 0.036199 | Val Loss: 0.037259
# Epoch  878/1000 | Train Loss: 0.036149 | Val Loss: 0.039518
# Epoch  879/1000 | Train Loss: 0.036750 | Val Loss: 0.037672
# Epoch  880/1000 | Train Loss: 0.036729 | Val Loss: 0.036406
# Epoch  881/1000 | Train Loss: 0.035974 | Val Loss: 0.037655
# Epoch  882/1000 | Train Loss: 0.036414 | Val Loss: 0.040788
# Epoch  883/1000 | Train Loss: 0.036052 | Val Loss: 0.036202
# Epoch  884/1000 | Train Loss: 0.037498 | Val Loss: 0.039338
# Epoch  885/1000 | Train Loss: 0.036662 | Val Loss: 0.039504
# Epoch  886/1000 | Train Loss: 0.038290 | Val Loss: 0.034322
# Epoch  887/1000 | Train Loss: 0.037704 | Val Loss: 0.035307
# Epoch  888/1000 | Train Loss: 0.038141 | Val Loss: 0.038085
# Epoch  889/1000 | Train Loss: 0.037118 | Val Loss: 0.039389
# Epoch  890/1000 | Train Loss: 0.036316 | Val Loss: 0.039010
# Epoch  891/1000 | Train Loss: 0.037207 | Val Loss: 0.034735
# Epoch  892/1000 | Train Loss: 0.038072 | Val Loss: 0.038564
# Epoch  893/1000 | Train Loss: 0.036583 | Val Loss: 0.035817
# Epoch  894/1000 | Train Loss: 0.038052 | Val Loss: 0.043439
# Epoch  895/1000 | Train Loss: 0.036046 | Val Loss: 0.036502
# Epoch  896/1000 | Train Loss: 0.037026 | Val Loss: 0.039235
# Epoch  897/1000 | Train Loss: 0.037497 | Val Loss: 0.037938
# Epoch  898/1000 | Train Loss: 0.037203 | Val Loss: 0.040219
# Epoch  899/1000 | Train Loss: 0.037466 | Val Loss: 0.036512
# Epoch  900/1000 | Train Loss: 0.037815 | Val Loss: 0.037422
# Epoch  901/1000 | Train Loss: 0.037039 | Val Loss: 0.040137
# Epoch  902/1000 | Train Loss: 0.035562 | Val Loss: 0.036935
# Epoch  903/1000 | Train Loss: 0.037021 | Val Loss: 0.035146
# Epoch  904/1000 | Train Loss: 0.036616 | Val Loss: 0.033791
# Epoch  905/1000 | Train Loss: 0.037532 | Val Loss: 0.038180
# Epoch  906/1000 | Train Loss: 0.037326 | Val Loss: 0.034385
# Epoch  907/1000 | Train Loss: 0.037500 | Val Loss: 0.037699
# Epoch  908/1000 | Train Loss: 0.035741 | Val Loss: 0.035757
# Epoch  909/1000 | Train Loss: 0.036473 | Val Loss: 0.037102
# Epoch  910/1000 | Train Loss: 0.037446 | Val Loss: 0.033951
# Epoch  911/1000 | Train Loss: 0.036747 | Val Loss: 0.039216
# Epoch  912/1000 | Train Loss: 0.036293 | Val Loss: 0.040098
# Epoch  913/1000 | Train Loss: 0.037776 | Val Loss: 0.035653
# Epoch  914/1000 | Train Loss: 0.037446 | Val Loss: 0.037529
# Epoch  915/1000 | Train Loss: 0.036480 | Val Loss: 0.039346
# Epoch  916/1000 | Train Loss: 0.037851 | Val Loss: 0.041272
# Epoch  917/1000 | Train Loss: 0.037243 | Val Loss: 0.036948
# Epoch  918/1000 | Train Loss: 0.037345 | Val Loss: 0.037184
# Epoch  919/1000 | Train Loss: 0.037127 | Val Loss: 0.039170
# Epoch  920/1000 | Train Loss: 0.037645 | Val Loss: 0.036045
# Epoch  921/1000 | Train Loss: 0.036284 | Val Loss: 0.035253
# Epoch  922/1000 | Train Loss: 0.037020 | Val Loss: 0.036421
# Epoch  923/1000 | Train Loss: 0.038164 | Val Loss: 0.033349
# Epoch  924/1000 | Train Loss: 0.035955 | Val Loss: 0.037199
# Epoch  925/1000 | Train Loss: 0.037268 | Val Loss: 0.038439
# Epoch  926/1000 | Train Loss: 0.037872 | Val Loss: 0.036290
# Epoch  927/1000 | Train Loss: 0.036868 | Val Loss: 0.035285
# Epoch  928/1000 | Train Loss: 0.036471 | Val Loss: 0.038726
# Epoch  929/1000 | Train Loss: 0.037522 | Val Loss: 0.041050
# Epoch  930/1000 | Train Loss: 0.036994 | Val Loss: 0.037695
# Epoch  931/1000 | Train Loss: 0.036861 | Val Loss: 0.039564
# Epoch  932/1000 | Train Loss: 0.036671 | Val Loss: 0.036866
# Epoch  933/1000 | Train Loss: 0.037077 | Val Loss: 0.034781
# Epoch  934/1000 | Train Loss: 0.038363 | Val Loss: 0.034213
# Epoch  935/1000 | Train Loss: 0.036971 | Val Loss: 0.035438
# Epoch  936/1000 | Train Loss: 0.038086 | Val Loss: 0.035889
# Epoch  937/1000 | Train Loss: 0.037345 | Val Loss: 0.040281
# Epoch  938/1000 | Train Loss: 0.035451 | Val Loss: 0.032027
#   New best model saved (val_loss=0.032027)
# Epoch  939/1000 | Train Loss: 0.038396 | Val Loss: 0.037589
# Epoch  940/1000 | Train Loss: 0.036649 | Val Loss: 0.038230
# Epoch  941/1000 | Train Loss: 0.037324 | Val Loss: 0.037764
# Epoch  942/1000 | Train Loss: 0.035912 | Val Loss: 0.039490
# Epoch  943/1000 | Train Loss: 0.036320 | Val Loss: 0.037264
# Epoch  944/1000 | Train Loss: 0.036528 | Val Loss: 0.037505
# Epoch  945/1000 | Train Loss: 0.036792 | Val Loss: 0.036564
# Epoch  946/1000 | Train Loss: 0.036850 | Val Loss: 0.034977
# Epoch  947/1000 | Train Loss: 0.036545 | Val Loss: 0.034970
# Epoch  948/1000 | Train Loss: 0.036420 | Val Loss: 0.037561
# Epoch  949/1000 | Train Loss: 0.035773 | Val Loss: 0.036679
# Epoch  950/1000 | Train Loss: 0.037001 | Val Loss: 0.036514
# Epoch  951/1000 | Train Loss: 0.037616 | Val Loss: 0.036874
# Epoch  952/1000 | Train Loss: 0.037042 | Val Loss: 0.037238
# Epoch  953/1000 | Train Loss: 0.036963 | Val Loss: 0.036783
# Epoch  954/1000 | Train Loss: 0.037359 | Val Loss: 0.038673
# Epoch  955/1000 | Train Loss: 0.037037 | Val Loss: 0.037734
# Epoch  956/1000 | Train Loss: 0.037245 | Val Loss: 0.037960
# Epoch  957/1000 | Train Loss: 0.037153 | Val Loss: 0.044998
# Epoch  958/1000 | Train Loss: 0.036567 | Val Loss: 0.039501
# Epoch  959/1000 | Train Loss: 0.037738 | Val Loss: 0.035855
# Epoch  960/1000 | Train Loss: 0.037366 | Val Loss: 0.035656
# Epoch  961/1000 | Train Loss: 0.035858 | Val Loss: 0.036211
# Epoch  962/1000 | Train Loss: 0.036649 | Val Loss: 0.035840
# Epoch  963/1000 | Train Loss: 0.034985 | Val Loss: 0.038215
# Epoch  964/1000 | Train Loss: 0.036273 | Val Loss: 0.037489
# Epoch  965/1000 | Train Loss: 0.038173 | Val Loss: 0.035683
# Epoch  966/1000 | Train Loss: 0.037588 | Val Loss: 0.038275
# Epoch  967/1000 | Train Loss: 0.036818 | Val Loss: 0.038947
# Epoch  968/1000 | Train Loss: 0.036771 | Val Loss: 0.037336
# Epoch  969/1000 | Train Loss: 0.036363 | Val Loss: 0.038214
# Epoch  970/1000 | Train Loss: 0.035753 | Val Loss: 0.039233
# Epoch  971/1000 | Train Loss: 0.037769 | Val Loss: 0.035437
# Epoch  972/1000 | Train Loss: 0.037806 | Val Loss: 0.031466
#   New best model saved (val_loss=0.031466)
# Epoch  973/1000 | Train Loss: 0.036278 | Val Loss: 0.038880
# Epoch  974/1000 | Train Loss: 0.037198 | Val Loss: 0.039976
# Epoch  975/1000 | Train Loss: 0.036565 | Val Loss: 0.035099
# Epoch  976/1000 | Train Loss: 0.037568 | Val Loss: 0.035865
# Epoch  977/1000 | Train Loss: 0.036284 | Val Loss: 0.039682
# Epoch  978/1000 | Train Loss: 0.036919 | Val Loss: 0.037284
# Epoch  979/1000 | Train Loss: 0.037371 | Val Loss: 0.037415
# Epoch  980/1000 | Train Loss: 0.037589 | Val Loss: 0.039133
# Epoch  981/1000 | Train Loss: 0.037625 | Val Loss: 0.036203
# Epoch  982/1000 | Train Loss: 0.036097 | Val Loss: 0.037870
# Epoch  983/1000 | Train Loss: 0.035804 | Val Loss: 0.038045
# Epoch  984/1000 | Train Loss: 0.038006 | Val Loss: 0.038581
# Epoch  985/1000 | Train Loss: 0.037369 | Val Loss: 0.038314
# Epoch  986/1000 | Train Loss: 0.036297 | Val Loss: 0.037225
# Epoch  987/1000 | Train Loss: 0.035753 | Val Loss: 0.035264
# Epoch  988/1000 | Train Loss: 0.036344 | Val Loss: 0.035891
# Epoch  989/1000 | Train Loss: 0.036954 | Val Loss: 0.036512
# Epoch  990/1000 | Train Loss: 0.036141 | Val Loss: 0.034819
# Epoch  991/1000 | Train Loss: 0.036957 | Val Loss: 0.038718
# Epoch  992/1000 | Train Loss: 0.036044 | Val Loss: 0.035598
# Epoch  993/1000 | Train Loss: 0.037457 | Val Loss: 0.034961
# Epoch  994/1000 | Train Loss: 0.036687 | Val Loss: 0.036646
# Epoch  995/1000 | Train Loss: 0.037165 | Val Loss: 0.035961
# Epoch  996/1000 | Train Loss: 0.037652 | Val Loss: 0.036655
# Epoch  997/1000 | Train Loss: 0.035933 | Val Loss: 0.038904
# Epoch  998/1000 | Train Loss: 0.038195 | Val Loss: 0.035538
# Epoch  999/1000 | Train Loss: 0.037192 | Val Loss: 0.037864
# Epoch 1000/1000 | Train Loss: 0.036834 | Val Loss: 0.037090
# Training done.

# %%
p_min_np = xmin[:NUM_BUS]
p_max_np = xmax[:NUM_BUS]
q_min_np = xmin[NUM_BUS:2 * NUM_BUS]
q_max_np = xmax[NUM_BUS:2 * NUM_BUS]
v_min_np = xmin[2 * NUM_BUS:3 * NUM_BUS]
v_max_np = xmax[2 * NUM_BUS:3 * NUM_BUS]

p_min = torch.tensor(p_min_np, device=DEVICE, dtype=torch.float32)
p_max = torch.tensor(p_max_np, device=DEVICE, dtype=torch.float32)
q_min = torch.tensor(q_min_np, device=DEVICE, dtype=torch.float32)
q_max = torch.tensor(q_max_np, device=DEVICE, dtype=torch.float32)
v_min = torch.tensor(v_min_np, device=DEVICE, dtype=torch.float32)
v_max = torch.tensor(v_max_np, device=DEVICE, dtype=torch.float32)

def power_residuals(x_den):
    p = x_den[:, :NUM_BUS]
    q = x_den[:, NUM_BUS:2 * NUM_BUS]
    v = x_den[:, 2 * NUM_BUS:3 * NUM_BUS]
    th = x_den[:, 3 * NUM_BUS:4 * NUM_BUS]

    th_r = th * math.pi / 180

    vb = v.unsqueeze(-1)
    vj = v.unsqueeze(-2)
    dth = th_r.unsqueeze(-1) - th_r.unsqueeze(-2)

    cosd = torch.cos(dth)
    sind = torch.sin(dth)

    G_b = G.unsqueeze(0)
    B_b = B.unsqueeze(0)

    P = (vb * vj * (G_b * cosd + B_b * sind)).sum(dim=-1)
    Q = (vb * vj * (G_b * sind - B_b * cosd)).sum(dim=-1)

    return torch.cat([p - P, q - Q], dim=1)


def RH_sq(x_den):
    return (power_residuals(x_den) ** 2).sum(dim=1)


def RG_sq(x_den: torch.Tensor) -> torch.Tensor:
    p = x_den[:, :NUM_BUS]
    q = x_den[:, NUM_BUS:2 * NUM_BUS]
    v = x_den[:, 2 * NUM_BUS:3 * NUM_BUS]

    viol_p_upper = torch.relu(p - p_max)
    viol_p_lower = torch.relu(p_min - p)
    viol_q_upper = torch.relu(q - q_max)
    viol_q_lower = torch.relu(q_min - q)
    viol_v_upper = torch.relu(v - v_max)
    viol_v_lower = torch.relu(v_min - v)

    viol = torch.cat(
        [
            viol_p_upper, viol_p_lower,
            viol_q_upper, viol_q_lower,
            viol_v_upper, viol_v_lower,
        ],
        dim=1,
    )

    return (viol ** 2).sum(dim=1)


def make_ddim_timesteps(ddim_steps):
    step = TIMESTEPS // ddim_steps
    return torch.arange(TIMESTEPS - 1, -1, -step, device=DEVICE, dtype=torch.long)


print("Sampling using stochastic DDIM with physics guidance...")

n_samples = SAMPLE_COUNT
x_t = torch.randn(n_samples, NUM_FEATURES, device=DEVICE)
re = torch.tensor(range_eps, device=DEVICE, dtype=torch.float32)
xm = torch.tensor(xmin, device=DEVICE, dtype=torch.float32)
timesteps = make_ddim_timesteps(DDIM_STEPS)

for step_idx, t_idx in enumerate(tqdm(timesteps.tolist(), desc="Stochastic DDIM Sampling")):
    t = torch.full((n_samples,), t_idx, device=DEVICE, dtype=torch.long)

    with torch.no_grad():
        eps_pred = model(x_t, t)
        sA = torch.sqrt(alphas_cumprod[t]).unsqueeze(1)
        sO = torch.sqrt(1 - alphas_cumprod[t]).unsqueeze(1)
        x0 = (x_t - sO * eps_pred) / sA

    x_den = ((x0 + 1.0) / 2.0) * re + xm
    x_den = x_den.detach().clone().requires_grad_(True)

    R_total = RH_sq(x_den) + RG_sq(x_den)

    g_phys = grad(R_total.sum(), x_den, retain_graph=False, create_graph=False)[0]

    grad_norm = g_phys * (re / 2.0)
    lam_t = GUIDANCE_LAMBDA * ((t.float() + 1.0) / TIMESTEPS).unsqueeze(1)

    x0_guided = x0 - lam_t * grad_norm
    x0_guided = torch.clamp(x0_guided, -1.0, 1.0)

    a_bar_t = alphas_cumprod[t].unsqueeze(1)

    if step_idx < len(timesteps) - 1:
        t_prev_idx = timesteps[step_idx + 1].item()
        t_prev = torch.full((n_samples,), t_prev_idx, device=DEVICE, dtype=torch.long)
        a_bar_prev = alphas_cumprod[t_prev].unsqueeze(1)
    else:
        a_bar_prev = torch.ones_like(a_bar_t)
        t_prev_idx = -1

    if t_prev_idx == -1:
        x_t = x0_guided.detach()
        continue

    denom = (1.0 - a_bar_t).clamp(min=1e-8)
    eps_pred = (x_t - torch.sqrt(a_bar_t) * x0_guided) / torch.sqrt(denom)

    frac = ((1.0 - a_bar_prev) / denom).clamp(min=0.0)
    inner = (1.0 - (a_bar_t / a_bar_prev)).clamp(min=0.0)
    sigma = ETA * torch.sqrt(frac * inner)

    sigma2 = sigma * sigma
    sqrt_term = (1.0 - a_bar_prev - sigma2).clamp(min=0.0)
    sqrt_term = torch.sqrt(sqrt_term)

    x_prev_mean = torch.sqrt(a_bar_prev) * x0_guided + sqrt_term * eps_pred
    z = torch.randn_like(x_t)
    x_t = x_prev_mean + sigma * z
    x_t = x_t.detach()

gen_norm = x_t.cpu().numpy()
gen_denorm = denormalize(gen_norm)

bad = ~np.isfinite(gen_denorm)
if bad.any():
    print(f"[warn] {bad.sum()} invalid values detected; replacing with finite values.")
    gen_denorm = np.nan_to_num(
        gen_denorm,
        nan=0.0,
        posinf=0.0,
        neginf=0.0
    )

pd.DataFrame(gen_denorm, columns=cols).to_csv(
    OUT_CSV,
    index=False
)

print(f"\nGenerated {len(gen_denorm)} stochastic-DDIM guided samples → {OUT_CSV}")
# Out:
# Sampling using stochastic DDIM with physics guidance...
# Stochastic DDIM Sampling: 100%|██████████| 334/334 [00:33<00:00,  9.87it/s]
# Generated 5000 stochastic-DDIM guided samples → ddim_stochastic_constrained_generated.csv

# %%
generated = pd.read_csv(OUT_CSV)

p_cols = [c for c in actual.columns if c.startswith("P")]
q_cols = [c for c in actual.columns if c.startswith("Q")]
v_cols = [c for c in actual.columns if c.startswith("V")]
theta_cols = [c for c in actual.columns if c.startswith("Th")]

num_buses = len(p_cols)

actual_nonpu = actual.copy()
generated_nonpu = generated.copy()

for col in p_cols:
    actual_nonpu[col] = actual[col] * BASE_MVA
    generated_nonpu[col] = generated[col] * BASE_MVA

for col in q_cols:
    actual_nonpu[col] = actual[col] * BASE_MVA
    generated_nonpu[col] = generated[col] * BASE_MVA

vn_kv = net.bus.vn_kv.values
for i, col in enumerate(v_cols):
    actual_nonpu[col] = actual[col] * vn_kv[i]
    generated_nonpu[col] = generated[col] * vn_kv[i]


fig, axes = plt.subplots(2, 6, figsize=(24, 8))

for i in range(NUM_BUS):
    bus_id = i + 1

    p_col = f"P{i}"
    q_col = f"Q{i}"
    v_col = f"V{i}"
    th_col = f"Theta{i}"

    ax1 = axes[0, i]
    ax1.scatter(actual_nonpu[p_col], actual_nonpu[q_col], alpha=0.2, s=5, label="Actual")
    ax1.scatter(generated_nonpu[p_col], generated_nonpu[q_col], alpha=0.2, s=5, label="Generated")
    ax1.set_title(f"Bus {bus_id}: P{bus_id} vs Q{bus_id}")
    ax1.set_xlabel("P (MW)")
    ax1.set_ylabel("Q (Mvar)")
    ax1.legend(fontsize=8)

    ax2 = axes[1, i]
    ax2.scatter(actual_nonpu[v_col], actual_nonpu[th_col], alpha=0.2, s=5, label="Actual")
    ax2.scatter(generated_nonpu[v_col], generated_nonpu[th_col], alpha=0.2, s=5, label="Generated")
    ax2.set_title(f"Bus {bus_id}: V{bus_id} vs Theta{bus_id}")
    ax2.set_xlabel("V (kV)")
    ax2.set_ylabel("Theta (deg)")
    ax2.legend(fontsize=8)

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(4, 6, figsize=(18, 12))
axes = axes.flatten()

bus_offset = 1

for idx, col in enumerate(actual_nonpu.columns):
    ax = axes[idx]

    if col.startswith("Theta") and col[5:].isdigit():
        display_bus = int(col[5:]) + bus_offset
        label = f"Theta{display_bus}"
    elif col.startswith("Th") and col[2:].isdigit():
        display_bus = int(col[2:]) + bus_offset
        label = f"Theta{display_bus}"
    elif col[1:].isdigit():
        display_bus = int(col[1:]) + bus_offset
        label = f"{col[0]}{display_bus}"
    else:
        label = col

    ax.hist(actual_nonpu[col], bins=40, alpha=0.6, density=True, label='Actual')
    ax.hist(generated_nonpu[col], bins=40, alpha=0.6, density=True, label='Generated')
    ax.set_title(f"{label}")
    ax.legend(fontsize=8)

for j in range(idx + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
from scipy.spatial.distance import cdist
from scipy.stats import entropy

def calculate_w1_distance_for_eta(actual_df, gen_df):
    distances = []

    cols = (
        p_cols +
        q_cols +
        v_cols +
        theta_cols
    )

    actual_df[theta_cols] = np.deg2rad(actual_df[theta_cols])
    gen_df[theta_cols] = np.deg2rad(gen_df[theta_cols])

    data_gt = actual_df[cols].values
    data_syn = gen_df[cols].values

    n = len(data_gt)
    m = len(data_syn)

    a = np.ones(n) / n
    b = np.ones(m) / m

    M = cdist(data_gt, data_syn, metric='euclidean')

    wasserstein_dist = ot.emd2(a, b, M)
    distances.append(wasserstein_dist)

    print("P Q V Theta W1 distance:", wasserstein_dist)
    return wasserstein_dist

def kl_divergence_featurewise(actual_df, gen_df, bins=80, eps=1e-12):
    actual = actual_df.copy()
    gen = gen_df.copy()

    theta_cols = [c for c in actual.columns if "Theta" in c]

    if len(theta_cols) > 0:
        actual[theta_cols] = np.deg2rad(actual[theta_cols])
        gen[theta_cols] = np.deg2rad(gen[theta_cols])

    cols = actual.columns.tolist()
    data_gt = actual.values
    data_syn = gen.values

    kl_results = {}

    for i, col in enumerate(cols):
        real_vals = data_gt[:, i]
        test_vals = data_syn[:, i]

        hist_range = (
            min(real_vals.min(), test_vals.min()),
            max(real_vals.max(), test_vals.max())
        )

        real_hist, _ = np.histogram(real_vals, bins=bins, range=hist_range, density=True)
        test_hist, _ = np.histogram(test_vals, bins=bins, range=hist_range, density=True)

        real_hist += eps
        test_hist += eps

        real_hist /= real_hist.sum()
        test_hist /= test_hist.sum()

        kl = entropy(real_hist, test_hist)
        kl_results[col] = kl

    return pd.DataFrame(kl_results, index=["KL"]).T

calculate_w1_distance_for_eta(actual, generated)

kl = kl_divergence_featurewise(actual, generated)
print(kl)
print("KL Mean:", kl["KL"].mean())
# Out:
# P Q V Theta W1 distance: 0.01680441986786806
#               KL
# P0      0.067022
# P1      0.021726
# P2      0.031030
# P3      0.015647
# P4      0.016844
# P5      0.019242
# Q0      0.030798
# Q1      0.025414
# Q2      0.017677
# Q3      0.014467
# Q4      0.015547
# Q5      0.017341
# V0      0.000000
# V1      0.000000
# V2      0.000000
# V3      0.012072
# V4      0.017410
# V5      0.019401
# Theta0  0.360396
# Theta1  0.062220
# Theta2  0.125506
# Theta3  0.028235
# Theta4  0.122498
# Theta5  0.138941
# KL Mean: 0.049143119259431024
# /usr/local/lib/python3.12/dist-packages/ot/lp/_network_simplex.py:574: UserWarning: numItermax reached before optimality. Try to increase numItermax.
#   check_result(result_code)
